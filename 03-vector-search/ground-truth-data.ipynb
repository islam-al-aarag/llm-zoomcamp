# %%
import requests 

docs_url = 'https://github.com/DataTalksClub/llm-zoomcamp/blob/main/01-intro/documents.json?raw=1'
docs_response = requests.get(docs_url)
documents_raw = docs_response.json()

documents = []

for course in documents_raw:
    course_name = course['course']

    for doc in course['documents']:
        doc['course'] = course_name
        documents.append(doc)

# %%
import hashlib

def generate_document_id(doc):
    combined = f"{doc['course']}-{doc['question']}-{doc['text'][:10]}"
    hash_object = hashlib.md5(combined.encode())
    hash_hex = hash_object.hexdigest()
    document_id = hash_hex[:8]
    return document_id

# %%
for doc in documents:
    doc['id'] = generate_document_id(doc)

# %%
documents[0]
# Out:
# {'text': "The purpose of this document is to capture frequently asked technical questions\nThe exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  “Office Hours'' live.1\nSubscribe to course public Google Calendar (it works from Desktop only).\nRegister before the course starts using this link.\nJoin the course Telegram channel with announcements.\nDon’t forget to register in DataTalks.Club's Slack and join the channel.",
#  'section': 'General course-related questions',
#  'question': 'Course - When will the course start?',
#  'course': 'data-engineering-zoomcamp',
#  'id': 'c02e79ef'}

# %%
from collections import defaultdict
hashes = defaultdict(list)

for doc in documents:
    doc_id = doc['id']
    hashes[doc_id].append(doc)

# %%
import json
with open('documents-with-ids.json', 'wt') as f_out:
    json.dump(documents, f_out, indent=2)

# %%
prompt_template = """
You emulate a student who's taking our course.
Formulate 5 questions this student might ask based on a FAQ record. The record
should contain the answer to the questions, and the questions should be complete and not too short.
If possible, use as few words as possible from the record. 

The record:

section: {section}
question: {question}
answer: {text}

Provide the output in parsable JSON without using code blocks:

["question1", "question2", ..., "question5"]
""".strip()

# %%
from openai import OpenAI
client = OpenAI()

# %%
def generate_questions(doc):
    prompt = prompt_template.format(**doc)

    response = client.chat.completions.create(
        model='gpt-4o',
        messages=[{"role": "user", "content": prompt}]
    )

    json_response = response.choices[0].message.content
    return json_response

# %%
from tqdm.auto import tqdm

# %%
results = {}
for doc in tqdm(documents): 
    doc_id = doc['id']
    if doc_id in results:
        continue

    questions = generate_questions(doc)
    results[doc_id] = questions
# Out:
#   0%|          | 0/948 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 7
#       4 if doc_id in results:
#       5     continue
# ----> 7 questions = generate_questions(doc)
#       8 results[doc_id] = questions
#
# Cell In[12], line 4, in generate_questions(doc)
#       1 def generate_questions(doc):
#       2     prompt = prompt_template.format(**doc)
# ----> 4     response = client.chat.completions.create(
#       5         model='gpt-4o',
#       6         messages=[{"role": "user", "content": prompt}]
#       7     )
#       9     json_response = response.choices[0].message.content
#      10     return json_response
#
# File ~/Desktop/llm-zoomcamp/llm_zoomcamp_venv/lib/python3.9/site-packages/openai/_utils/_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File ~/Desktop/llm-zoomcamp/llm_zoomcamp_venv/lib/python3.9/site-packages/openai/resources/chat/completions.py:643, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     609 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     610 def create(
#     611     self,
#    (...)
#     641     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     642 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 643     return self._post(
#     644         "/chat/completions",
#     645         body=maybe_transform(
#     646             {
#     647                 "messages": messages,
#     648                 "model": model,
#     649                 "frequency_penalty": frequency_penalty,
#     650                 "function_call": function_call,
#     651                 "functions": functions,
#     652                 "logit_bias": logit_bias,
#     653                 "logprobs": logprobs,
#     654                 "max_tokens": max_tokens,
#     655                 "n": n,
#     656                 "parallel_tool_calls": parallel_tool_calls,
#     657                 "presence_penalty": presence_penalty,
#     658                 "response_format": response_format,
#     659                 "seed": seed,
#     660                 "service_tier": service_tier,
#     661                 "stop": stop,
#     662                 "stream": stream,
#     663                 "stream_options": stream_options,
#     664                 "temperature": temperature,
#     665                 "tool_choice": tool_choice,
#     666                 "tools": tools,
#     667                 "top_logprobs": top_logprobs,
#     668                 "top_p": top_p,
#     669                 "user": user,
#     670             },
#     671             completion_create_params.CompletionCreateParams,
#     672         ),
#     673         options=make_request_options(
#     674             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     675         ),
#     676         cast_to=ChatCompletion,
#     677         stream=stream or False,
#     678         stream_cls=Stream[ChatCompletionChunk],
#     679     )
#
# File ~/Desktop/llm-zoomcamp/llm_zoomcamp_venv/lib/python3.9/site-packages/openai/_base_client.py:1261, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1247 def post(
#    1248     self,
#    1249     path: str,
#    (...)
#    1256     stream_cls: type[_StreamT] | None = None,
#    1257 ) -> ResponseT | _StreamT:
#    1258     opts = FinalRequestOptions.construct(
#    1259         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1260     )
# -> 1261     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Desktop/llm-zoomcamp/llm_zoomcamp_venv/lib/python3.9/site-packages/openai/_base_client.py:942, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     933 def request(
#     934     self,
#     935     cast_to: Type[ResponseT],
#    (...)
#     940     stream_cls: type[_StreamT] | None = None,
#     941 ) -> ResponseT | _StreamT:
# --> 942     return self._request(
#     943         cast_to=cast_to,
#     944         options=options,
#     945         stream=stream,
#     946         stream_cls=stream_cls,
#     947         remaining_retries=remaining_retries,
#     948     )
#
# File ~/Desktop/llm-zoomcamp/llm_zoomcamp_venv/lib/python3.9/site-packages/openai/_base_client.py:973, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     970 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     972 try:
# --> 973     response = self._client.send(
#     974         request,
#     975         stream=stream or self._should_stream_response_body(request=request),
#     976         **kwargs,
#     977     )
#     978 except httpx.TimeoutException as err:
#     979     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/Desktop/llm-zoomcamp/llm_zoomcamp_venv/lib/python3.9/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Desktop/llm-zoomcamp/llm_zoomcamp_venv/lib/python3.9/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Desktop/llm-zoomcamp/llm_zoomcamp_venv/lib/python3.9/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Desktop/llm-zoomcamp/llm_zoomcamp_venv/lib/python3.9/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File ~/Desktop/llm-zoomcamp/llm_zoomcamp_venv/lib/python3.9/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File ~/Desktop/llm-zoomcamp/llm_zoomcamp_venv/lib/python3.9/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File ~/Desktop/llm-zoomcamp/llm_zoomcamp_venv/lib/python3.9/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~/Desktop/llm-zoomcamp/llm_zoomcamp_venv/lib/python3.9/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File ~/Desktop/llm-zoomcamp/llm_zoomcamp_venv/lib/python3.9/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File ~/Desktop/llm-zoomcamp/llm_zoomcamp_venv/lib/python3.9/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File ~/Desktop/llm-zoomcamp/llm_zoomcamp_venv/lib/python3.9/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File ~/Desktop/llm-zoomcamp/llm_zoomcamp_venv/lib/python3.9/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Desktop/llm-zoomcamp/llm_zoomcamp_venv/lib/python3.9/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/ssl.py:1227, in SSLSocket.recv(self, buflen, flags)
#    1223     if flags != 0:
#    1224         raise ValueError(
#    1225             "non-zero flags not allowed in calls to recv() on %s" %
#    1226             self.__class__)
# -> 1227     return self.read(buflen)
#    1228 else:
#    1229     return super().recv(buflen, flags)
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/ssl.py:1102, in SSLSocket.read(self, len, buffer)
#    1100         return self._sslobj.read(len, buffer)
#    1101     else:
# -> 1102         return self._sslobj.read(len)
#    1103 except SSLError as x:
#    1104     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
import pickle
with open('results.bin', 'rb') as f_in:
    results = pickle.load(f_in)
# Out:
# 29

# %%
import pandas as pd
file_path = 'ground-truth-data.csv'
df = pd.read_csv(file_path)

# %%
for _, json_questions in df.iterrows():
    print (json_questions)
# Out:
# question    When does the course begin?
# course        data-engineering-zoomcamp
# document                       c02e79ef
# Name: 0, dtype: object
# question    How can I get the course schedule?
# course               data-engineering-zoomcamp
# document                              c02e79ef
# Name: 1, dtype: object
# question    What is the link for course registration?
# course                      data-engineering-zoomcamp
# document                                     c02e79ef
# Name: 2, dtype: object
# question    How can I receive course announcements?
# course                    data-engineering-zoomcamp
# document                                   c02e79ef
# Name: 3, dtype: object
# question    Where do I join the Slack channel?
# course               data-engineering-zoomcamp
# document                              c02e79ef
# Name: 4, dtype: object
# question    Where can I find the prerequisites for this co...
# course                              data-engineering-zoomcamp
# document                                             1f6520ca
# Name: 5, dtype: object
# question    How do I check the prerequisites for this course?
# course                              data-engineering-zoomcamp
# document                                             1f6520ca
# Name: 6, dtype: object
# question    Where are the course prerequisites listed?
# course                       data-engineering-zoomcamp
# document                                      1f6520ca
# Name: 7, dtype: object
# question    What are the requirements for joining this cou...
# course                              data-engineering-zoomcamp
# document                                             1f6520ca
# Name: 8, dtype: object
# question    Where is the list of prerequisites for the cou...
# course                              data-engineering-zoomcamp
# document                                             1f6520ca
# Name: 9, dtype: object
# question    Can I enroll in the course after it starts?
# course                        data-engineering-zoomcamp
# document                                       7842b56a
# Name: 10, dtype: object
# question    Is late registration possible?
# course           data-engineering-zoomcamp
# document                          7842b56a
# Name: 11, dtype: object
# question    Am I eligible to submit homework if I join late?
# course                             data-engineering-zoomcamp
# document                                            7842b56a
# Name: 12, dtype: object
# question    Are there deadlines for final projects if I jo...
# course                              data-engineering-zoomcamp
# document                                             7842b56a
# Name: 13, dtype: object
# question    Can I submit all assignments at the end of the...
# course                              data-engineering-zoomcamp
# document                                             7842b56a
# Name: 14, dtype: object
# question    When will I receive the confirmation email aft...
# course                              data-engineering-zoomcamp
# document                                             0bbf41ec
# Name: 15, dtype: object
# question    Do I need the confirmation email to start the ...
# course                              data-engineering-zoomcamp
# document                                             0bbf41ec
# Name: 16, dtype: object
# question    Can I begin learning and submitting homework w...
# course                              data-engineering-zoomcamp
# document                                             0bbf41ec
# Name: 17, dtype: object
# question    Is registration for the Data Engineering Bootc...
# course                              data-engineering-zoomcamp
# document                                             0bbf41ec
# Name: 18, dtype: object
# question    What is the purpose of registering for the Dat...
# course                              data-engineering-zoomcamp
# document                                             0bbf41ec
# Name: 19, dtype: object
# question                    question1
# course      data-engineering-zoomcamp
# document                     63394d91
# Name: 20, dtype: object
# question                    question2
# course      data-engineering-zoomcamp
# document                     63394d91
# Name: 21, dtype: object
# question                    question3
# course      data-engineering-zoomcamp
# document                     63394d91
# Name: 22, dtype: object
# question                    question4
# course      data-engineering-zoomcamp
# document                     63394d91
# Name: 23, dtype: object
# question                    question5
# course      data-engineering-zoomcamp
# document                     63394d91
# Name: 24, dtype: object
# question    How many Zoom Camps are held each year?
# course                    data-engineering-zoomcamp
# document                                   2ed9b986
# Name: 25, dtype: object
# question    Are the Zoom Camps held for the same course?
# course                         data-engineering-zoomcamp
# document                                        2ed9b986
# Name: 26, dtype: object
# question    When does the Data-Engineering Zoom Camp take ...
# course                              data-engineering-zoomcamp
# document                                             2ed9b986
# Name: 27, dtype: object
# question    Is there more than one Data-Engineering Zoom C...
# course                              data-engineering-zoomcamp
# document                                             2ed9b986
# Name: 28, dtype: object
# question    Can I take the Zoom Camps at my own pace?
# course                      data-engineering-zoomcamp
# document                                     2ed9b986
# Name: 29, dtype: object
# question    Is Mage AI being used in the 2024 cohort?
# course                      data-engineering-zoomcamp
# document                                     93e2c8ed
# Name: 30, dtype: object
# question    Were the terraform videos re-recorded for the ...
# course                              data-engineering-zoomcamp
# document                                             93e2c8ed
# Name: 31, dtype: object
# question    Was Prefect used in the 2023 edition of the co...
# course                              data-engineering-zoomcamp
# document                                             93e2c8ed
# Name: 32, dtype: object
# question    Will the 2024 edition have differences from th...
# course                              data-engineering-zoomcamp
# document                                             93e2c8ed
# Name: 33, dtype: object
# question    Is Airflow being used in the 2023 edition inst...
# course                              data-engineering-zoomcamp
# document                                             93e2c8ed
# Name: 34, dtype: object
# question    Can I access the course materials after the co...
# course                              data-engineering-zoomcamp
# document                                             a482086d
# Name: 35, dtype: object
# question    Is it possible to continue looking at the home...
# course                              data-engineering-zoomcamp
# document                                             a482086d
# Name: 36, dtype: object
# question    Can I work at my own pace after the course is ...
# course                              data-engineering-zoomcamp
# document                                             a482086d
# Name: 37, dtype: object
# question    Will the material be available for preparing f...
# course                              data-engineering-zoomcamp
# document                                             a482086d
# Name: 38, dtype: object
# question    Can I start working on my final capstone proje...
# course                              data-engineering-zoomcamp
# document                                             a482086d
# Name: 39, dtype: object
# question    Can I receive support while taking the self-pa...
# course                              data-engineering-zoomcamp
# document                                             eb56ae98
# Name: 40, dtype: object
# question    Is there an open channel for questions in the ...
# course                              data-engineering-zoomcamp
# document                                             eb56ae98
# Name: 41, dtype: object
# question    Should I check anything before asking a questi...
# course                              data-engineering-zoomcamp
# document                                             eb56ae98
# Name: 42, dtype: object
# question    How can the @ZoomcampQABot assist me in the se...
# course                              data-engineering-zoomcamp
# document                                             eb56ae98
# Name: 43, dtype: object
# question    Is the @ZoomcampQABot completely reliable for ...
# course                              data-engineering-zoomcamp
# document                                             eb56ae98
# Name: 44, dtype: object
# question    Which YouTube playlist contains all the main c...
# course                              data-engineering-zoomcamp
# document                                             4292531b
# Name: 45, dtype: object
# question    How can I access the course videos directly fr...
# course                              data-engineering-zoomcamp
# document                                             4292531b
# Name: 46, dtype: object
# question    Where can I find year-specific playlists for a...
# course                              data-engineering-zoomcamp
# document                                             4292531b
# Name: 47, dtype: object
# question    Is there a direct link to the Main 'DATA ENGIN...
# course                              data-engineering-zoomcamp
# document                                             4292531b
# Name: 48, dtype: object
# question    Where is the main playlist pinned in the commu...
# course                              data-engineering-zoomcamp
# document                                             4292531b
# Name: 49, dtype: object
# question    How many weekly hours should I dedicate to thi...
# course                              data-engineering-zoomcamp
# document                                             ea739c65
# Name: 50, dtype: object
# question    What is the estimated time commitment for this...
# course                              data-engineering-zoomcamp
# document                                             ea739c65
# Name: 51, dtype: object
# question    On average, how much time will this course tak...
# course                              data-engineering-zoomcamp
# document                                             ea739c65
# Name: 52, dtype: object
# question    What is the weekly expected study time for thi...
# course                              data-engineering-zoomcamp
# document                                             ea739c65
# Name: 53, dtype: object
# question    How many hours should I plan to spend on this ...
# course                              data-engineering-zoomcamp
# document                                             ea739c65
# Name: 54, dtype: object
# question    Can I receive a certificate if I complete the ...
# course                              data-engineering-zoomcamp
# document                                             cb257ee5
# Name: 55, dtype: object
# question    Is peer-review necessary for earning a certifi...
# course                              data-engineering-zoomcamp
# document                                             cb257ee5
# Name: 56, dtype: object
# question    Why am I unable to get a certificate for the s...
# course                              data-engineering-zoomcamp
# document                                             cb257ee5
# Name: 57, dtype: object
# question    Can I still earn a certificate if I don't part...
# course                              data-engineering-zoomcamp
# document                                             cb257ee5
# Name: 58, dtype: object
# question    Why are certificates awarded only during the t...
# course                              data-engineering-zoomcamp
# document                                             cb257ee5
# Name: 59, dtype: object
# question    Where is the zoom link for the office hours or...
# course                              data-engineering-zoomcamp
# document                                             04aa4897
# Name: 60, dtype: object
# question    How do students participate in the office hour...
# course                              data-engineering-zoomcamp
# document                                             04aa4897
# Name: 61, dtype: object
# question    Where can I find the video URL for the live se...
# course                              data-engineering-zoomcamp
# document                                             04aa4897
# Name: 62, dtype: object
# question    How should students submit questions during th...
# course                              data-engineering-zoomcamp
# document                                             04aa4897
# Name: 63, dtype: object
# question    Where should I not post my questions during th...
# course                              data-engineering-zoomcamp
# document                                             04aa4897
# Name: 64, dtype: object
# question    Will office hours be available if I miss them?
# course                           data-engineering-zoomcamp
# document                                          9681be3b
# Name: 65, dtype: object
# question    Can I rewatch a workshop later if I can't attend?
# course                              data-engineering-zoomcamp
# document                                             9681be3b
# Name: 66, dtype: object
# question    Are office hour sessions recorded for later vi...
# course                              data-engineering-zoomcamp
# document                                             9681be3b
# Name: 67, dtype: object
# question    Is there a way to access office hours after th...
# course                              data-engineering-zoomcamp
# document                                             9681be3b
# Name: 68, dtype: object
# question    What happens if I'm unable to attend the live ...
# course                              data-engineering-zoomcamp
# document                                             9681be3b
# Name: 69, dtype: object
# question    Where can I find updated deadlines for homewor...
# course                              data-engineering-zoomcamp
# document                                             a1daf537
# Name: 70, dtype: object
# question    Is there a specific place to look for extensio...
# course                              data-engineering-zoomcamp
# document                                             a1daf537
# Name: 71, dtype: object
# question    How will I know if there are any new updates a...
# course                              data-engineering-zoomcamp
# document                                             a1daf537
# Name: 72, dtype: object
# question    Who provides announcements about deadline exte...
# course                              data-engineering-zoomcamp
# document                                             a1daf537
# Name: 73, dtype: object
# question    What should I check if I need information on u...
# course                              data-engineering-zoomcamp
# document                                             a1daf537
# Name: 74, dtype: object
# question    Is it possible to submit homework after the du...
# course                              data-engineering-zoomcamp
# document                                             be5bfee4
# Name: 75, dtype: object
# question    What happens if the homework form is still ope...
# course                              data-engineering-zoomcamp
# document                                             be5bfee4
# Name: 76, dtype: object
# question    Can I confirm my late homework submission?
# course                       data-engineering-zoomcamp
# document                                      be5bfee4
# Name: 77, dtype: object
# question    Are there any exceptions for late homework sub...
# course                              data-engineering-zoomcamp
# document                                             be5bfee4
# Name: 78, dtype: object
# question    How do I verify the date-time of my homework s...
# course                              data-engineering-zoomcamp
# document                                             be5bfee4
# Name: 79, dtype: object
# question    What is the URL for submitting homework assign...
# course                              data-engineering-zoomcamp
# document                                             0e424a44
# Name: 80, dtype: object
# question    Where should I upload my homework code?
# course                    data-engineering-zoomcamp
# document                                   0e424a44
# Name: 81, dtype: object
# question    How can I share my homework repository?
# course                    data-engineering-zoomcamp
# document                                   0e424a44
# Name: 82, dtype: object
# question    What should the homework link contain?
# course                   data-engineering-zoomcamp
# document                                  0e424a44
# Name: 83, dtype: object
# question    Where will the instructor look for my homework?
# course                            data-engineering-zoomcamp
# document                                           0e424a44
# Name: 84, dtype: object
# question    How are homework assignments graded and how ca...
# course                              data-engineering-zoomcamp
# document                                             29865466
# Name: 85, dtype: object
# question    What points contribute to the leaderboard total?
# course                             data-engineering-zoomcamp
# document                                            29865466
# Name: 86, dtype: object
# question    How many points do I get for submitting an FAQ?
# course                            data-engineering-zoomcamp
# document                                           29865466
# Name: 87, dtype: object
# question    How many points do I earn for each learning in...
# course                              data-engineering-zoomcamp
# document                                             29865466
# Name: 88, dtype: object
# question    Where can I find the sum of all my points earn...
# course                              data-engineering-zoomcamp
# document                                             29865466
# Name: 89, dtype: object
# question    How do I see my display name for the leaderboard?
# course                              data-engineering-zoomcamp
# document                                             016d46a1
# Name: 90, dtype: object
# question    What do I do if I am not on the leaderboard?
# course                         data-engineering-zoomcamp
# document                                        016d46a1
# Name: 91, dtype: object
# question    How is my display name determined when I set u...
# course                              data-engineering-zoomcamp
# document                                             016d46a1
# Name: 92, dtype: object
# question    Can I change my display name and if so, how?
# course                         data-engineering-zoomcamp
# document                                        016d46a1
# Name: 93, dtype: object
# question    Where can I edit my course profile to find my ...
# course                              data-engineering-zoomcamp
# document                                             016d46a1
# Name: 94, dtype: object
# question    Is Python 3.9 recommended for our 2024 course?
# course                           data-engineering-zoomcamp
# document                                          47972cb1
# Name: 95, dtype: object
# question    Can we use Python 3.10 or 3.11 instead of 3.9?
# course                           data-engineering-zoomcamp
# document                                          47972cb1
# Name: 96, dtype: object
# question    Why is Python 3.9 still recommended in 2024?
# course                         data-engineering-zoomcamp
# document                                        47972cb1
# Name: 97, dtype: object
# question    Is Python 3.9 necessary for troubleshooting ag...
# course                              data-engineering-zoomcamp
# document                                             47972cb1
# Name: 98, dtype: object
# question    Are Python 3.10 and 3.11 suitable for use in t...
# course                              data-engineering-zoomcamp
# document                                             47972cb1
# Name: 99, dtype: object
# question    What are the recommended environments for sett...
# course                              data-engineering-zoomcamp
# document                                             ddf6c1b3
# Name: 100, dtype: object
# question    Can I set up the environment on my local machi...
# course                              data-engineering-zoomcamp
# document                                             ddf6c1b3
# Name: 101, dtype: object
# question    What should I do if I prefer working locally o...
# course                              data-engineering-zoomcamp
# document                                             ddf6c1b3
# Name: 102, dtype: object
# question    Are there any challenges for Windows users whe...
# course                              data-engineering-zoomcamp
# document                                             ddf6c1b3
# Name: 103, dtype: object
# question    Why might someone choose to use a virtual mach...
# course                              data-engineering-zoomcamp
# document                                             ddf6c1b3
# Name: 104, dtype: object
# question    Can I use GitHub Codespaces instead of cli/git...
# course                              data-engineering-zoomcamp
# document                                             ac25d3af
# Name: 105, dtype: object
# question    Does GitHub Codespaces come with pre-installed...
# course                              data-engineering-zoomcamp
# document                                             ac25d3af
# Name: 106, dtype: object
# question    Can I open a GitHub repository directly in a G...
# course                              data-engineering-zoomcamp
# document                                             ac25d3af
# Name: 107, dtype: object
# question    Is Docker available in GitHub Codespaces?
# course                      data-engineering-zoomcamp
# document                                     ac25d3af
# Name: 108, dtype: object
# question    Are computing Linux resources provided by GitH...
# course                              data-engineering-zoomcamp
# document                                             ac25d3af
# Name: 109, dtype: object
# question    Do I have to use GitHub Codespaces for the cou...
# course                              data-engineering-zoomcamp
# document                                             251218fc
# Name: 110, dtype: object
# question    Is it mandatory to use GCP VM or can I work fr...
# course                              data-engineering-zoomcamp
# document                                             251218fc
# Name: 111, dtype: object
# question    Is there flexibility in choosing the developme...
# course                              data-engineering-zoomcamp
# document                                             251218fc
# Name: 112, dtype: object
# question    Can I complete the course using PostgreSQL and...
# course                              data-engineering-zoomcamp
# document                                             251218fc
# Name: 113, dtype: object
# question    Are there any restrictions on the platforms we...
# course                              data-engineering-zoomcamp
# document                                             251218fc
# Name: 114, dtype: object
# question    Do I need both GitHub Codespaces and GCP for t...
# course                              data-engineering-zoomcamp
# document                                             3c0114ce
# Name: 115, dtype: object
# question    Which environment should I choose for my end p...
# course                              data-engineering-zoomcamp
# document                                             3c0114ce
# Name: 116, dtype: object
# question    Is BigQuery part of GCP used in the course?
# course                        data-engineering-zoomcamp
# document                                       3c0114ce
# Name: 117, dtype: object
# question    Is it possible to set up a local environment f...
# course                              data-engineering-zoomcamp
# document                                             3c0114ce
# Name: 118, dtype: object
# question    Is learning GCP a better option for this course?
# course                             data-engineering-zoomcamp
# document                                            3c0114ce
# Name: 119, dtype: object
# question    How can I open the Run command window to conne...
# course                              data-engineering-zoomcamp
# document                                             f43f5fe7
# Name: 120, dtype: object
# question    Where are the registry values located that nee...
# course                              data-engineering-zoomcamp
# document                                             f43f5fe7
# Name: 121, dtype: object
# question    What steps should I follow to change the 'Auto...
# course                              data-engineering-zoomcamp
# document                                             f43f5fe7
# Name: 122, dtype: object
# question    Is there an alternative solution to changing t...
# course                              data-engineering-zoomcamp
# document                                             f43f5fe7
# Name: 123, dtype: object
# question    Where is the known_hosts file located in Windo...
# course                              data-engineering-zoomcamp
# document                                             f43f5fe7
# Name: 124, dtype: object
# question    Why is GCP chosen as the primary cloud provide...
# course                              data-engineering-zoomcamp
# document                                             d061525d
# Name: 125, dtype: object
# question    Can I use AWS instead of GCP for this course?
# course                          data-engineering-zoomcamp
# document                                         d061525d
# Name: 126, dtype: object
# question    Does GCP offer any free trial or credits for n...
# course                              data-engineering-zoomcamp
# document                                             d061525d
# Name: 127, dtype: object
# question    Do I need a credit card to sign up for a free ...
# course                              data-engineering-zoomcamp
# document                                             d061525d
# Name: 128, dtype: object
# question    Is BigQuery exclusive to GCP?
# course          data-engineering-zoomcamp
# document                         d061525d
# Name: 129, dtype: object
# question    What are the payment options for cloud service...
# course                              data-engineering-zoomcamp
# document                                             1cd01b2c
# Name: 130, dtype: object
# question    Is there a way to use GCP without incurring co...
# course                              data-engineering-zoomcamp
# document                                             1cd01b2c
# Name: 131, dtype: object
# question    Do I need to budget for cloud services for thi...
# course                              data-engineering-zoomcamp
# document                                             1cd01b2c
# Name: 132, dtype: object
# question    Can I use Google Cloud Platform for free in th...
# course                              data-engineering-zoomcamp
# document                                             1cd01b2c
# Name: 133, dtype: object
# question    Are cloud service fees something I should be c...
# course                              data-engineering-zoomcamp
# document                                             1cd01b2c
# Name: 134, dtype: object
# question    Are there guidelines for setting up a home lab?
# course                            data-engineering-zoomcamp
# document                                           e4a7c3b0
# Name: 135, dtype: object
# question    Can I complete the course without using the cl...
# course                              data-engineering-zoomcamp
# document                                             e4a7c3b0
# Name: 136, dtype: object
# question    Is there a local alternative for everything in...
# course                              data-engineering-zoomcamp
# document                                             e4a7c3b0
# Name: 137, dtype: object
# question    Do I need GCP to run BigQuery only?
# course                data-engineering-zoomcamp
# document                               e4a7c3b0
# Name: 138, dtype: object
# question    Can the entire course be done locally?
# course                   data-engineering-zoomcamp
# document                                  e4a7c3b0
# Name: 139, dtype: object
# question    Can I use AWS for this course instead of GCP?
# course                          data-engineering-zoomcamp
# document                                         7cd1912e
# Name: 140, dtype: object
# question    What should I adapt if I use AWS for the course?
# course                             data-engineering-zoomcamp
# document                                            7cd1912e
# Name: 141, dtype: object
# question    Will my capstone project be graded if I use AWS?
# course                             data-engineering-zoomcamp
# document                                            7cd1912e
# Name: 142, dtype: object
# question    What kind of help can I expect if I decide to ...
# course                              data-engineering-zoomcamp
# document                                             7cd1912e
# Name: 143, dtype: object
# question    Where can I find information on using tools ot...
# course                              data-engineering-zoomcamp
# document                                             7cd1912e
# Name: 144, dtype: object
# question    What are 'Office Hour' live zoom calls?
# course                    data-engineering-zoomcamp
# document                                   52393fb3
# Name: 145, dtype: object
# question    Will there be additional live calls during the...
# course                              data-engineering-zoomcamp
# document                                             52393fb3
# Name: 146, dtype: object
# question    How will we be informed about additional calls?
# course                            data-engineering-zoomcamp
# document                                           52393fb3
# Name: 147, dtype: object
# question    Are Capstone period calls announced in advance?
# course                            data-engineering-zoomcamp
# document                                           52393fb3
# Name: 148, dtype: object
# question    Do Capstone calls help clear questions?
# course                    data-engineering-zoomcamp
# document                                   52393fb3
# Name: 149, dtype: object
# question                    questions
# course      data-engineering-zoomcamp
# document                     10515af5
# Name: 150, dtype: object
# question    Has the 2022 repository been removed?
# course                  data-engineering-zoomcamp
# document                                 cdb86a97
# Name: 151, dtype: object
# question    Where did the 2022 material go?
# course            data-engineering-zoomcamp
# document                           cdb86a97
# Name: 152, dtype: object
# question    Is the 2022 content still available?
# course                 data-engineering-zoomcamp
# document                                cdb86a97
# Name: 153, dtype: object
# question    Did you delete the 2022 repository?
# course                data-engineering-zoomcamp
# document                               cdb86a97
# Name: 154, dtype: object
# question    Where can I find the 2022 resources now?
# course                     data-engineering-zoomcamp
# document                                    cdb86a97
# Name: 155, dtype: object
# question    Can I choose any tool for my final project?
# course                        data-engineering-zoomcamp
# document                                       3e0114ad
# Name: 156, dtype: object
# question    Is it acceptable to use Airflow for the final ...
# course                              data-engineering-zoomcamp
# document                                             3e0114ad
# Name: 157, dtype: object
# question    Are there any restrictions on tools for the pr...
# course                              data-engineering-zoomcamp
# document                                             3e0114ad
# Name: 158, dtype: object
# question    May I use alternatives to the recommended tool...
# course                              data-engineering-zoomcamp
# document                                             3e0114ad
# Name: 159, dtype: object
# question    Can I substitute Airflow for the suggested too...
# course                              data-engineering-zoomcamp
# document                                             3e0114ad
# Name: 160, dtype: object
# question    Can I use Airflow instead of Mage for this cou...
# course                              data-engineering-zoomcamp
# document                                             b2799574
# Name: 161, dtype: object
# question    Is it okay to use AWS products instead of GCP ...
# course                              data-engineering-zoomcamp
# document                                             b2799574
# Name: 162, dtype: object
# question    Can I substitute Tableau for Metabase in this ...
# course                              data-engineering-zoomcamp
# document                                             b2799574
# Name: 163, dtype: object
# question    What alternatives are allowed for the local in...
# course                              data-engineering-zoomcamp
# document                                             b2799574
# Name: 164, dtype: object
# question    Will the course instructors support me if I ch...
# course                              data-engineering-zoomcamp
# document                                             b2799574
# Name: 165, dtype: object
# question    What should we do to contribute to the course?
# course                           data-engineering-zoomcamp
# document                                          2f19301f
# Name: 166, dtype: object
# question    How can we share the course with friends?
# course                      data-engineering-zoomcamp
# document                                     2f19301f
# Name: 167, dtype: object
# question    What action should we take on the repo for con...
# course                              data-engineering-zoomcamp
# document                                             2f19301f
# Name: 168, dtype: object
# question    Can we create a PR to improve the course mater...
# course                              data-engineering-zoomcamp
# document                                             2f19301f
# Name: 169, dtype: object
# question    What is the best way to support the course if ...
# course                              data-engineering-zoomcamp
# document                                             2f19301f
# Name: 170, dtype: object
# question    Does the course work well with Linux?
# course                  data-engineering-zoomcamp
# document                                 7c700adb
# Name: 171, dtype: object
# question    Can I use Windows for this course?
# course               data-engineering-zoomcamp
# document                              7c700adb
# Name: 172, dtype: object
# question    Is macOS compatible with the course material?
# course                          data-engineering-zoomcamp
# document                                         7c700adb
# Name: 173, dtype: object
# question    Have students used different operating systems...
# course                              data-engineering-zoomcamp
# document                                             7c700adb
# Name: 174, dtype: object
# question    Which operating system is considered ideal for...
# course                              data-engineering-zoomcamp
# document                                             7c700adb
# Name: 175, dtype: object
# question    Is it necessary to set up the WSL environment ...
# course                              data-engineering-zoomcamp
# document                                             44b14808
# Name: 176, dtype: object
# question    Why might Windows users not be able to continu...
# course                              data-engineering-zoomcamp
# document                                             44b14808
# Name: 177, dtype: object
# question    Are there any alternative solutions for runnin...
# course                              data-engineering-zoomcamp
# document                                             44b14808
# Name: 178, dtype: object
# question    What challenges could Windows users face in th...
# course                              data-engineering-zoomcamp
# document                                             44b14808
# Name: 179, dtype: object
# question    Has there been any discussion or solutions pro...
# course                              data-engineering-zoomcamp
# document                                             44b14808
# Name: 180, dtype: object
# question    Are there any extra resources or books you sug...
# course                              data-engineering-zoomcamp
# document                                             76e4baf6
# Name: 181, dtype: object
# question    Can you recommend any additional books for thi...
# course                              data-engineering-zoomcamp
# document                                             76e4baf6
# Name: 182, dtype: object
# question    Do you have any suggestions for further readin...
# course                              data-engineering-zoomcamp
# document                                             76e4baf6
# Name: 183, dtype: object
# question    Is there a list of recommended resources for t...
# course                              data-engineering-zoomcamp
# document                                             76e4baf6
# Name: 184, dtype: object
# question    Where can I find extra learning materials for ...
# course                              data-engineering-zoomcamp
# document                                             76e4baf6
# Name: 185, dtype: object
# question    What are Project Attempt #1 and Project Attemp...
# course                              data-engineering-zoomcamp
# document                                             48b533a8
# Name: 186, dtype: object
# question    Can I resubmit my project if I fail the first ...
# course                              data-engineering-zoomcamp
# document                                             48b533a8
# Name: 187, dtype: object
# question    What happens if I miss the first project deadl...
# course                              data-engineering-zoomcamp
# document                                             48b533a8
# Name: 188, dtype: object
# question    How many chances do I get to submit my project?
# course                            data-engineering-zoomcamp
# document                                           48b533a8
# Name: 189, dtype: object
# question    Is there a second deadline for project submiss...
# course                              data-engineering-zoomcamp
# document                                             48b533a8
# Name: 190, dtype: object
# question    What is the first step to troubleshoot an issu...
# course                              data-engineering-zoomcamp
# document                                             954044d1
# Name: 191, dtype: object
# question    How can I find specific information in documen...
# course                              data-engineering-zoomcamp
# document                                             954044d1
# Name: 192, dtype: object
# question    What should my Slack question include if I nee...
# course                              data-engineering-zoomcamp
# document                                             954044d1
# Name: 193, dtype: object
# question    Why should I avoid using screenshots when aski...
# course                              data-engineering-zoomcamp
# document                                             954044d1
# Name: 194, dtype: object
# question    What should I do if I can't resolve a technica...
# course                              data-engineering-zoomcamp
# document                                             954044d1
# Name: 195, dtype: object
# question    When should I ask a question if the troublesho...
# course                              data-engineering-zoomcamp
# document                                             a820b9b3
# Name: 196, dtype: object
# question    What details should I include about my OS when...
# course                              data-engineering-zoomcamp
# document                                             a820b9b3
# Name: 197, dtype: object
# question    Which information about the command I ran shou...
# course                              data-engineering-zoomcamp
# document                                             a820b9b3
# Name: 198, dtype: object
# question    Why is it important to mention what I have alr...
# course                              data-engineering-zoomcamp
# document                                             a820b9b3
# Name: 199, dtype: object
# question    What should I check if my error log has a line...
# course                              data-engineering-zoomcamp
# document                                             a820b9b3
# Name: 200, dtype: object
# question    How do I initially set up Git / GitHub for thi...
# course                              data-engineering-zoomcamp
# document                                             f2945cd2
# Name: 201, dtype: object
# question    Where can I find a tutorial for setting up my ...
# course                              data-engineering-zoomcamp
# document                                             f2945cd2
# Name: 202, dtype: object
# question    What types of files should I avoid saving in a...
# course                              data-engineering-zoomcamp
# document                                             f2945cd2
# Name: 203, dtype: object
# question    What should I never store in a Git repository,...
# course                              data-engineering-zoomcamp
# document                                             f2945cd2
# Name: 204, dtype: object
# question    What's a good resource for common Git issues?
# course                          data-engineering-zoomcamp
# document                                         f2945cd2
# Name: 205, dtype: object
# question    What can I do about the 'missing separator' er...
# course                              data-engineering-zoomcamp
# document                                             eb9d376f
# Name: 206, dtype: object
# question    How should I format the tabs in a Makefile to ...
# course                              data-engineering-zoomcamp
# document                                             eb9d376f
# Name: 207, dtype: object
# question    Why does my Makefile show '*** missing separat...
# course                              data-engineering-zoomcamp
# document                                             eb9d376f
# Name: 208, dtype: object
# question    What's the solution for missing separator erro...
# course                              data-engineering-zoomcamp
# document                                             eb9d376f
# Name: 209, dtype: object
# question    How do I fix tab-related issues in VS Code whe...
# course                              data-engineering-zoomcamp
# document                                             eb9d376f
# Name: 210, dtype: object
# question    How can I open HTML files with a Windows brows...
# course                              data-engineering-zoomcamp
# document                                             72f25f6d
# Name: 211, dtype: object
# question    What command do I use to open a page with wslv...
# course                              data-engineering-zoomcamp
# document                                             72f25f6d
# Name: 212, dtype: object
# question    How can I customize which browser wslview uses?
# course                            data-engineering-zoomcamp
# document                                           72f25f6d
# Name: 213, dtype: object
# question    What environment variable do I set to change t...
# course                              data-engineering-zoomcamp
# document                                             72f25f6d
# Name: 214, dtype: object
# question    Which WSL version allows opening HTML files wi...
# course                              data-engineering-zoomcamp
# document                                             72f25f6d
# Name: 215, dtype: object
# question    How do I set up Chrome Remote Desktop on a Com...
# course                              data-engineering-zoomcamp
# document                                             a1e59afc
# Name: 216, dtype: object
# question    What is the purpose of using Chrome Remote Des...
# course                              data-engineering-zoomcamp
# document                                             a1e59afc
# Name: 217, dtype: object
# question    What should I do if I encounter an ERROR 403: ...
# course                              data-engineering-zoomcamp
# document                                             a1e59afc
# Name: 218, dtype: object
# question    Where can I find the backup of the 2021 Yellow...
# course                              data-engineering-zoomcamp
# document                                             a1e59afc
# Name: 219, dtype: object
# question    How should I unzip the downloaded 'yellow_trip...
# course                              data-engineering-zoomcamp
# document                                             a1e59afc
# Name: 220, dtype: object
# question    How do I correctly store taxi data files now t...
# course                              data-engineering-zoomcamp
# document                                             71c10610
# Name: 221, dtype: object
# question    Why won't the data file store correctly if the...
# course                              data-engineering-zoomcamp
# document                                             71c10610
# Name: 222, dtype: object
# question    What is one alternative to replacing csv_name ...
# course                              data-engineering-zoomcamp
# document                                             71c10610
# Name: 223, dtype: object
# question    How can I parse the file name from the URL for...
# course                              data-engineering-zoomcamp
# document                                             71c10610
# Name: 224, dtype: object
# question    Can the pandas read_csv function read csv.gz f...
# course                              data-engineering-zoomcamp
# document                                             71c10610
# Name: 225, dtype: object
# question    Where can I find the data dictionary for Yello...
# course                              data-engineering-zoomcamp
# document                                             17a5aea1
# Name: 226, dtype: object
# question    Where is the data dictionary for Green Taxi tr...
# course                              data-engineering-zoomcamp
# document                                             17a5aea1
# Name: 227, dtype: object
# question    Can you provide the URL for the Yellow Taxi tr...
# course                              data-engineering-zoomcamp
# document                                             17a5aea1
# Name: 228, dtype: object
# question    What is the link to the Green Taxi trip data d...
# course                              data-engineering-zoomcamp
# document                                             17a5aea1
# Name: 229, dtype: object
# question    Where do I find information about NY Yellow Tr...
# course                              data-engineering-zoomcamp
# document                                             17a5aea1
# Name: 230, dtype: object
# question    How do I unzip a downloaded parquet file in th...
# course                              data-engineering-zoomcamp
# document                                             5a275db7
# Name: 231, dtype: object
# question    What is the command line instruction to unzip ...
# course                              data-engineering-zoomcamp
# document                                             5a275db7
# Name: 232, dtype: object
# question    Can I import unzipped csv files using pandas, ...
# course                              data-engineering-zoomcamp
# document                                             5a275db7
# Name: 233, dtype: object
# question    How do I modify ingest_data.py to work directl...
# course                              data-engineering-zoomcamp
# document                                             5a275db7
# Name: 234, dtype: object
# question    What is the correct way to convert a downloade...
# course                              data-engineering-zoomcamp
# document                                             5a275db7
# Name: 235, dtype: object
# ...
# document                                             19a3d34a
# Name: 4551, dtype: object
# question    What is causing the 'Unable to locate credenti...
# course                                         mlops-zoomcamp
# document                                             55c68f23
# Name: 4552, dtype: object
# question    How can I fix the error message 'Unable to loc...
# course                                         mlops-zoomcamp
# document                                             55c68f23
# Name: 4553, dtype: object
# question    What environment variables need to be added in...
# course                                         mlops-zoomcamp
# document                                             55c68f23
# Name: 4554, dtype: object
# question    Do the values of AWS_ACCESS_KEY_ID and AWS_SEC...
# course                                         mlops-zoomcamp
# document                                             55c68f23
# Name: 4555, dtype: object
# question    What command can be used as an alternative sol...
# course                                         mlops-zoomcamp
# document                                             55c68f23
# Name: 4556, dtype: object
# question    Why do I get an error about an incompatible lo...
# course                                         mlops-zoomcamp
# document                                             54020f0a
# Name: 4557, dtype: object
# question    What is the exact error message when creating ...
# course                                         mlops-zoomcamp
# document                                             54020f0a
# Name: 4558, dtype: object
# question    How can I fix the IllegalLocationConstraintExc...
# course                                         mlops-zoomcamp
# document                                             54020f0a
# Name: 4559, dtype: object
# question    What change in the create_bucket method helps ...
# course                                         mlops-zoomcamp
# document                                             54020f0a
# Name: 4560, dtype: object
# question    Which parameter should be added to the create_...
# course                                         mlops-zoomcamp
# document                                             54020f0a
# Name: 4561, dtype: object
# question    How can I fix the error <botocore.awsrequest.A...
# course                                         mlops-zoomcamp
# document                                             b6249d2c
# Name: 4562, dtype: object
# question    What are the steps to resolve the error <botoc...
# course                                         mlops-zoomcamp
# document                                             b6249d2c
# Name: 4563, dtype: object
# question    What environment variables should I set to fix...
# course                                         mlops-zoomcamp
# document                                             b6249d2c
# Name: 4564, dtype: object
# question    Is the value of AWS_DEFAULT_REGION, AWS_ACCESS...
# course                                         mlops-zoomcamp
# document                                             b6249d2c
# Name: 4565, dtype: object
# question    Who provided the solution for the AWS CLI erro...
# course                                         mlops-zoomcamp
# document                                             b6249d2c
# Name: 4566, dtype: object
# question    What should I check if I get a mapping values ...
# course                                         mlops-zoomcamp
# document                                             31543d95
# Name: 4567, dtype: object
# question    What does the error 'mapping values are not al...
# course                                         mlops-zoomcamp
# document                                             31543d95
# Name: 4568, dtype: object
# question    How do I fix the 'mapping values' error in my ...
# course                                         mlops-zoomcamp
# document                                             31543d95
# Name: 4569, dtype: object
# question    Why aren't pre-commit hooks running due to a m...
# course                                         mlops-zoomcamp
# document                                             31543d95
# Name: 4570, dtype: object
# question    What specific indentation is required in .pre-...
# course                                         mlops-zoomcamp
# document                                             31543d95
# Name: 4571, dtype: object
# question    What should I do if I can't reconfigure pytest...
# course                                         mlops-zoomcamp
# document                                             e147bbb6
# Name: 4572, dtype: object
# question    How can I delete previous pytest configurations?
# course                                        mlops-zoomcamp
# document                                            e147bbb6
# Name: 4573, dtype: object
# question    What folder should be removed to reset pytest ...
# course                                         mlops-zoomcamp
# document                                             e147bbb6
# Name: 4574, dtype: object
# question    How do I reconfigure pytest if tests were prev...
# course                                         mlops-zoomcamp
# document                                             e147bbb6
# Name: 4575, dtype: object
# question    Which folder contains the .vscode directory th...
# course                                         mlops-zoomcamp
# document                                             e147bbb6
# Name: 4576, dtype: object
# question    In Module 6, how can I fix the issue of gettin...
# course                                         mlops-zoomcamp
# document                                             dc55657f
# Name: 4577, dtype: object
# question    What additional flag should I add to the Kines...
# course                                         mlops-zoomcamp
# document                                             dc55657f
# Name: 4578, dtype: object
# question    How do I modify the Kinesis get records call t...
# course                                         mlops-zoomcamp
# document                                             dc55657f
# Name: 4579, dtype: object
# question    What workaround is provided in the solution fo...
# course                                         mlops-zoomcamp
# document                                             dc55657f
# Name: 4580, dtype: object
# question    In video 6.3 at minute 11:23, what should I ad...
# course                                         mlops-zoomcamp
# document                                             dc55657f
# Name: 4581, dtype: object
# question    What is the error when executing git commit af...
# course                                         mlops-zoomcamp
# document                                             f6979915
# Name: 4582, dtype: object
# question    Which file is causing the utf-8 encoding error...
# course                                         mlops-zoomcamp
# document                                             f6979915
# Name: 4583, dtype: object
# question    What is the error message for the utf-8 encodi...
# course                                         mlops-zoomcamp
# document                                             f6979915
# Name: 4584, dtype: object
# question    How can I solve the utf-8 encoding error when ...
# course                                         mlops-zoomcamp
# document                                             f6979915
# Name: 4585, dtype: object
# question    Who provided the solution for setting utf-8 en...
# course                                         mlops-zoomcamp
# document                                             f6979915
# Name: 4586, dtype: object
# question    How can I fix the error 'PythonInfo' object ha...
# course                                         mlops-zoomcamp
# document                                             1076a121
# Name: 4587, dtype: object
# question    What is indicated by the error 'AttributeError...
# course                                         mlops-zoomcamp
# document                                             1076a121
# Name: 4588, dtype: object
# question    What does the return code 1 signify when encou...
# course                                         mlops-zoomcamp
# document                                             1076a121
# Name: 4589, dtype: object
# question    Who added the solution for fixing the 'PythonI...
# course                                         mlops-zoomcamp
# document                                             1076a121
# Name: 4590, dtype: object
# question    What commands should be used to clear app-data...
# course                                         mlops-zoomcamp
# document                                             1076a121
# Name: 4591, dtype: object
# question    What should I do if I get a 'module not found'...
# course                                         mlops-zoomcamp
# document                                             aa203ca7
# Name: 4592, dtype: object
# question    Why does running 'pytest ./test/unit_tests' re...
# course                                         mlops-zoomcamp
# document                                             aa203ca7
# Name: 4593, dtype: object
# question    What is the correct command to run tests with ...
# course                                         mlops-zoomcamp
# document                                             aa203ca7
# Name: 4594, dtype: object
# question    Why does running 'python test_model_service.py...
# course                                         mlops-zoomcamp
# document                                             aa203ca7
# Name: 4595, dtype: object
# question    How can I ensure Pytest can find my custom pac...
# course                                         mlops-zoomcamp
# document                                             aa203ca7
# Name: 4596, dtype: object
# question    What is the solution when 'No module named pro...
# course                                         mlops-zoomcamp
# document                                             8b04605d
# Name: 4597, dtype: object
# question    What changes need to be made in the pre-commit...
# course                                         mlops-zoomcamp
# document                                             8b04605d
# Name: 4598, dtype: object
# question    Why does git commit -t 'test' raise 'No module...
# course                                         mlops-zoomcamp
# document                                             8b04605d
# Name: 4599, dtype: object
# question    How should the run.sh file be configured to se...
# course                                         mlops-zoomcamp
# document                                             8b04605d
# Name: 4600, dtype: object
# question    What export command should be used in run.sh t...
# course                                         mlops-zoomcamp
# document                                             8b04605d
# Name: 4601, dtype: object
# question    What is the error code associated with a permi...
# course                                         mlops-zoomcamp
# document                                             a3b9af04
# Name: 4602, dtype: object
# question    Where should the unit tests script be located ...
# course                                         mlops-zoomcamp
# document                                             a3b9af04
# Name: 4603, dtype: object
# question    What command should I use to add execution per...
# course                                         mlops-zoomcamp
# document                                             a3b9af04
# Name: 4604, dtype: object
# question    Who provided the solution to the permission de...
# course                                         mlops-zoomcamp
# document                                             a3b9af04
# Name: 4605, dtype: object
# question    What is a common permission error encountered ...
# course                                         mlops-zoomcamp
# document                                             a3b9af04
# Name: 4606, dtype: object
# question    How can I manage resource usage when my docker...
# course                                         mlops-zoomcamp
# document                                             b16aae74
# Name: 4607, dtype: object
# question    What can I do to run only a specific group of ...
# course                                         mlops-zoomcamp
# document                                             b16aae74
# Name: 4608, dtype: object
# question    What command should I use to start a service w...
# course                                         mlops-zoomcamp
# document                                             b16aae74
# Name: 4609, dtype: object
# question    How do I define a profile for a service in a d...
# course                                         mlops-zoomcamp
# document                                             b16aae74
# Name: 4610, dtype: object
# question    Who contributed the solution for managing mult...
# course                                         mlops-zoomcamp
# document                                             b16aae74
# Name: 4611, dtype: object
# question    What should you verify if facing problems with...
# course                                         mlops-zoomcamp
# document                                             66326a87
# Name: 4612, dtype: object
# question    How can mismatched AWS regions affect your int...
# course                                         mlops-zoomcamp
# document                                             66326a87
# Name: 4613, dtype: object
# question    What file should be checked to ensure the AWS ...
# course                                         mlops-zoomcamp
# document                                             66326a87
# Name: 4614, dtype: object
# question    What is an example of setting the AWS region i...
# course                                         mlops-zoomcamp
# document                                             66326a87
# Name: 4615, dtype: object
# question    Who provided the solution for AWS region setti...
# course                                         mlops-zoomcamp
# document                                             66326a87
# Name: 4616, dtype: object
# question    What should I do if the Pre-commit command fai...
# course                                         mlops-zoomcamp
# document                                             fb3c4150
# Name: 4617, dtype: object
# question    Which version of isort should be set to fix th...
# course                                         mlops-zoomcamp
# document                                             fb3c4150
# Name: 4618, dtype: object
# question    Who provided the solution to the Pre-commit is...
# course                                         mlops-zoomcamp
# document                                             fb3c4150
# Name: 4619, dtype: object
# question    Can you tell me the module where Pre-commit is...
# course                                         mlops-zoomcamp
# document                                             fb3c4150
# Name: 4620, dtype: object
# question    What is the recommended isort version for Pre-...
# course                                         mlops-zoomcamp
# document                                             fb3c4150
# Name: 4621, dtype: object
# question    How should I destroy infrastructure created us...
# course                                         mlops-zoomcamp
# document                                             886d1617
# Name: 4622, dtype: object
# question    What is the first step to destroy AWS infrastr...
# course                                         mlops-zoomcamp
# document                                             886d1617
# Name: 4623, dtype: object
# question    Can I destroy infrastructure created with GitH...
# course                                         mlops-zoomcamp
# document                                             886d1617
# Name: 4624, dtype: object
# question    What command initializes Terraform with specif...
# course                                         mlops-zoomcamp
# document                                             886d1617
# Name: 4625, dtype: object
# question    How do you specify the variable file when runn...
# course                                         mlops-zoomcamp
# document                                             886d1617
# Name: 4626, dtype: object

# %%
parsed_results = defaultdict(list)

for _, result in df.iterrows():
    parsed_results[result['document']].append(result['question'])

# %%
parsed_results
# Out:
# defaultdict(list,
#             {'c02e79ef': ['When does the course begin?',
#               'How can I get the course schedule?',
#               'What is the link for course registration?',
#               'How can I receive course announcements?',
#               'Where do I join the Slack channel?'],
#              '1f6520ca': ['Where can I find the prerequisites for this course?',
#               'How do I check the prerequisites for this course?',
#               'Where are the course prerequisites listed?',
#               'What are the requirements for joining this course?',
#               'Where is the list of prerequisites for the course?'],
#              '7842b56a': ['Can I enroll in the course after it starts?',
#               'Is late registration possible?',
#               'Am I eligible to submit homework if I join late?',
#               'Are there deadlines for final projects if I join late?',
#               'Can I submit all assignments at the end of the course if I start late?'],
#              '0bbf41ec': ['When will I receive the confirmation email after registering for the Data Engineering Bootcamp?',
#               'Do I need the confirmation email to start the Data Engineering Bootcamp?',
#               'Can I begin learning and submitting homework without registering for the Data Engineering Bootcamp?',
#               'Is registration for the Data Engineering Bootcamp mandatory to start the course?',
#               'What is the purpose of registering for the Data Engineering Bootcamp if it is not mandatory?'],
#              '63394d91': ['question1',
#               'question2',
#               'question3',
#               'question4',
#               'question5'],
#              '2ed9b986': ['How many Zoom Camps are held each year?',
#               'Are the Zoom Camps held for the same course?',
#               'When does the Data-Engineering Zoom Camp take place?',
#               'Is there more than one Data-Engineering Zoom Camp cohort each year?',
#               'Can I take the Zoom Camps at my own pace?'],
#              '93e2c8ed': ['Is Mage AI being used in the 2024 cohort?',
#               'Were the terraform videos re-recorded for the 2024 cohort?',
#               'Was Prefect used in the 2023 edition of the course?',
#               'Will the 2024 edition have differences from the 2023 cohort?',
#               'Is Airflow being used in the 2023 edition instead of Prefect?'],
#              'a482086d': ['Can I access the course materials after the course finishes?',
#               'Is it possible to continue looking at the homework after the course ends?',
#               'Can I work at my own pace after the course is complete?',
#               'Will the material be available for preparing for the next cohort?',
#               'Can I start working on my final capstone project after the course ends?'],
#              'eb56ae98': ['Can I receive support while taking the self-paced course?',
#               'Is there an open channel for questions in the self-paced mode?',
#               'Should I check anything before asking a question on Slack?',
#               'How can the @ZoomcampQABot assist me in the self-paced course?',
#               'Is the @ZoomcampQABot completely reliable for course-related questions?'],
#              '4292531b': ['Which YouTube playlist contains all the main course videos?',
#               'How can I access the course videos directly from the GitHub repository?',
#               'Where can I find year-specific playlists for additional videos like office hours?',
#               "Is there a direct link to the Main 'DATA ENGINEERING' playlist on YouTube?",
#               'Where is the main playlist pinned in the communication channels?'],
#              'ea739c65': ['How many weekly hours should I dedicate to this course?',
#               'What is the estimated time commitment for this course per week?',
#               'On average, how much time will this course take each week?',
#               'What is the weekly expected study time for this course?',
#               'How many hours should I plan to spend on this course every week?'],
#              'cb257ee5': ['Can I receive a certificate if I complete the course at my own pace?',
#               'Is peer-review necessary for earning a certificate?',
#               'Why am I unable to get a certificate for the self-paced course?',
#               "Can I still earn a certificate if I don't participate in a live cohort?",
#               'Why are certificates awarded only during the time course is running?'],
#              '04aa4897': ['Where is the zoom link for the office hours or workshop sessions?',
#               'How do students participate in the office hours or workshop sessions?',
#               'Where can I find the video URL for the live sessions before they begin?',
#               'How should students submit questions during the live session?',
#               'Where should I not post my questions during the live session to ensure they are answered?'],
#              '9681be3b': ['Will office hours be available if I miss them?',
#               "Can I rewatch a workshop later if I can't attend?",
#               'Are office hour sessions recorded for later viewing?',
#               "Is there a way to access office hours after they've ended?",
#               "What happens if I'm unable to attend the live office hours?"],
#              'a1daf537': ['Where can I find updated deadlines for homework and projects?',
#               'Is there a specific place to look for extensions to deadlines?',
#               'How will I know if there are any new updates about project deadlines?',
#               'Who provides announcements about deadline extensions or other news?',
#               'What should I check if I need information on updated deadlines from the Instructor(s)?'],
#              'be5bfee4': ['Is it possible to submit homework after the due date?',
#               'What happens if the homework form is still open after the due date?',
#               'Can I confirm my late homework submission?',
#               'Are there any exceptions for late homework submissions?',
#               'How do I verify the date-time of my homework submission?'],
#              '0e424a44': ['What is the URL for submitting homework assignments?',
#               'Where should I upload my homework code?',
#               'How can I share my homework repository?',
#               'What should the homework link contain?',
#               'Where will the instructor look for my homework?'],
#              '29865466': ['How are homework assignments graded and how can I see my points?',
#               'What points contribute to the leaderboard total?',
#               'How many points do I get for submitting an FAQ?',
#               'How many points do I earn for each learning in public link?',
#               'Where can I find the sum of all my points earned in the course?'],
#              '016d46a1': ['How do I see my display name for the leaderboard?',
#               'What do I do if I am not on the leaderboard?',
#               'How is my display name determined when I set up my account?',
#               'Can I change my display name and if so, how?',
#               'Where can I edit my course profile to find my display name?'],
#              '47972cb1': ['Is Python 3.9 recommended for our 2024 course?',
#               'Can we use Python 3.10 or 3.11 instead of 3.9?',
#               'Why is Python 3.9 still recommended in 2024?',
#               'Is Python 3.9 necessary for troubleshooting against recorded videos?',
#               'Are Python 3.10 and 3.11 suitable for use in the course?'],
#              'ddf6c1b3': ['What are the recommended environments for setting up the course?',
#               'Can I set up the environment on my local machine for this course?',
#               'What should I do if I prefer working locally on my laptop or PC?',
#               'Are there any challenges for Windows users when setting up the local environment?',
#               'Why might someone choose to use a virtual machine for this course?'],
#              'ac25d3af': ['Can I use GitHub Codespaces instead of cli/git bash for data ingestion and Docker file creation?',
#               'Does GitHub Codespaces come with pre-installed tools?',
#               'Can I open a GitHub repository directly in a GitHub Codespace?',
#               'Is Docker available in GitHub Codespaces?',
#               'Are computing Linux resources provided by GitHub Codespaces?'],
#              '251218fc': ['Do I have to use GitHub Codespaces for the course, or can I use my own setup?',
#               'Is it mandatory to use GCP VM or can I work from my laptop?',
#               'Is there flexibility in choosing the development environment for this course?',
#               'Can I complete the course using PostgreSQL and Docker installed on my local machine?',
#               'Are there any restrictions on the platforms we can use for the course?'],
#              '3c0114ce': ['Do I need both GitHub Codespaces and GCP for this course?',
#               'Which environment should I choose for my end project in the course?',
#               'Is BigQuery part of GCP used in the course?',
#               'Is it possible to set up a local environment for this course?',
#               'Is learning GCP a better option for this course?'],
#              'f43f5fe7': ['How can I open the Run command window to connect to a GCP VM using VSCode on a Windows machine?',
#               'Where are the registry values located that need to be changed for connecting to a GCP VM using VSCode on a Windows machine?',
#               "What steps should I follow to change the 'Autorun' registry value to connect to a GCP VM using VSCode on a Windows machine?",
#               'Is there an alternative solution to changing the registry values to connect to a GCP VM using VSCode on a Windows machine?',
#               'Where is the known_hosts file located in Windows if I need to delete the fingerprint to connect to a GCP VM using VSCode?'],
#              'd061525d': ['Why is GCP chosen as the primary cloud provider for this course?',
#               'Can I use AWS instead of GCP for this course?',
#               'Does GCP offer any free trial or credits for new users?',
#               'Do I need a credit card to sign up for a free GCP account?',
#               'Is BigQuery exclusive to GCP?'],
#              '1cd01b2c': ['What are the payment options for cloud services during the course?',
#               'Is there a way to use GCP without incurring costs?',
#               'Do I need to budget for cloud services for this course?',
#               'Can I use Google Cloud Platform for free in this course?',
#               'Are cloud service fees something I should be concerned about?'],
#              'e4a7c3b0': ['Are there guidelines for setting up a home lab?',
#               'Can I complete the course without using the cloud?',
#               'Is there a local alternative for everything in the course?',
#               'Do I need GCP to run BigQuery only?',
#               'Can the entire course be done locally?'],
#              '7cd1912e': ['Can I use AWS for this course instead of GCP?',
#               'What should I adapt if I use AWS for the course?',
#               'Will my capstone project be graded if I use AWS?',
#               'What kind of help can I expect if I decide to use AWS?',
#               'Where can I find information on using tools other than the ones specified?'],
#              '52393fb3': ["What are 'Office Hour' live zoom calls?",
#               'Will there be additional live calls during the Capstone period?',
#               'How will we be informed about additional calls?',
#               'Are Capstone period calls announced in advance?',
#               'Do Capstone calls help clear questions?'],
#              '10515af5': ['questions'],
#              'cdb86a97': ['Has the 2022 repository been removed?',
#               'Where did the 2022 material go?',
#               'Is the 2022 content still available?',
#               'Did you delete the 2022 repository?',
#               'Where can I find the 2022 resources now?'],
#              '3e0114ad': ['Can I choose any tool for my final project?',
#               'Is it acceptable to use Airflow for the final project?',
#               'Are there any restrictions on tools for the project?',
#               'May I use alternatives to the recommended tools for my project?',
#               'Can I substitute Airflow for the suggested tools in the final project?'],
#              'b2799574': ['Can I use Airflow instead of Mage for this course?',
#               'Is it okay to use AWS products instead of GCP tools?',
#               'Can I substitute Tableau for Metabase in this course?',
#               'What alternatives are allowed for the local installation?',
#               'Will the course instructors support me if I choose a different tech stack?'],
#              '2f19301f': ['What should we do to contribute to the course?',
#               'How can we share the course with friends?',
#               'What action should we take on the repo for contributing?',
#               'Can we create a PR to improve the course material?',
#               'What is the best way to support the course if we find it useful?'],
#              '7c700adb': ['Does the course work well with Linux?',
#               'Can I use Windows for this course?',
#               'Is macOS compatible with the course material?',
#               'Have students used different operating systems in the past?',
#               'Which operating system is considered ideal for this course?'],
#              '44b14808': ['Is it necessary to set up the WSL environment from the beginning for Windows users?',
#               'Why might Windows users not be able to continue later modules without WSL?',
#               "Are there any alternative solutions for running shell scripts on Windows if I don't use WSL?",
#               'What challenges could Windows users face in the module-05 & RisingWave workshop?',
#               'Has there been any discussion or solutions provided in old Slack messages regarding shell scripts on Windows?'],
#              '76e4baf6': ['Are there any extra resources or books you suggest for the course?',
#               'Can you recommend any additional books for this course?',
#               'Do you have any suggestions for further reading materials?',
#               'Is there a list of recommended resources for the course?',
#               'Where can I find extra learning materials for this course?'],
#              '48b533a8': ['What are Project Attempt #1 and Project Attempt #2?',
#               'Can I resubmit my project if I fail the first attempt?',
#               'What happens if I miss the first project deadline?',
#               'How many chances do I get to submit my project?',
#               'Is there a second deadline for project submission?'],
#              '954044d1': ['What is the first step to troubleshoot an issue on my own?',
#               'How can I find specific information in documentation or online resources when I encounter an error?',
#               'What should my Slack question include if I need further assistance after trying to solve an issue?',
#               'Why should I avoid using screenshots when asking questions about errors?',
#               "What should I do if I can't resolve a technical issue immediately after taking a break?"],
#              'a820b9b3': ['When should I ask a question if the troubleshooting guide does not help?',
#               'What details should I include about my OS when asking a question?',
#               'Which information about the command I ran should be provided when asking a question?',
#               'Why is it important to mention what I have already tried?',
#               "What should I check if my error log has a line number for the 'offending' code?"],
#              'f2945cd2': ['How do I initially set up Git / GitHub for this course?',
#               'Where can I find a tutorial for setting up my own Git repository for notes?',
#               'What types of files should I avoid saving in a Git repository?',
#               "What should I never store in a Git repository, even if it's private?",
#               "What's a good resource for common Git issues?"],
#              'eb9d376f': ["What can I do about the 'missing separator' error in VS Code?",
#               'How should I format the tabs in a Makefile to avoid errors?',
#               "Why does my Makefile show '*** missing separator. Stop.'?",
#               "What's the solution for missing separator error in a Makefile?",
#               'How do I fix tab-related issues in VS Code when working with Makefiles?'],
#              '72f25f6d': ['How can I open HTML files with a Windows browser from Linux on WSL?',
#               'What command do I use to open a page with wslview?',
#               'How can I customize which browser wslview uses?',
#               'What environment variable do I set to change the browser used by wslview?',
#               'Which WSL version allows opening HTML files with Windows browsers?'],
#              'a1e59afc': ['How do I set up Chrome Remote Desktop on a Compute Engine Debian Linux VM?',
#               'What is the purpose of using Chrome Remote Desktop on a Debian Linux VM in Compute Engine?',
#               'What should I do if I encounter an ERROR 403: Forbidden while downloading 2021 Yellow Taxi data from the TLC website?',
#               "Where can I find the backup of the 2021 Yellow Taxi Trip Records if the original link doesn't work?",
#               "How should I unzip the downloaded 'yellow_tripdata_2021-01.csv.gz' file?"],
#              '71c10610': ['How do I correctly store taxi data files now that they are available as *.csv.gz?',
#               "Why won't the data file store correctly if the file extension is csv.gz instead of csv?",
#               "What is one alternative to replacing csv_name = 'output.csv' in the video?",
#               'How can I parse the file name from the URL for yellow taxi data?',
#               'Can the pandas read_csv function read csv.gz files directly without issues?'],
#              '17a5aea1': ['Where can I find the data dictionary for Yellow Taxi trips?',
#               'Where is the data dictionary for Green Taxi trips?',
#               'Can you provide the URL for the Yellow Taxi trip data dictionary?',
#               'What is the link to the Green Taxi trip data dictionary?',
#               'Where do I find information about NY Yellow Trip records?'],
#              '5a275db7': ['How do I unzip a downloaded parquet file in the command line as shown in Module 1?',
#               'What is the command line instruction to unzip the green_tripdata_2019-09.csv.gz file?',
#               'Can I import unzipped csv files using pandas, and if so, how?',
#               'How do I modify ingest_data.py to work directly with parquet files?',
#               'What is the correct way to convert a downloaded .parquet file to a .csv file in a Python script?'],
#              '7ec0f9b0': ['questions'],
#              'bb1ba786': ['How can I resolve wget certificate verification error in MacOS while using a Jupyter Notebook or CLI?',
#               "What should I add before wget if I'm running a command in a Jupyter Notebook?",
#               'How can I use the Python library wget installed with pip to verify a website certificate?',
#               'What is the command to use wget without checking the certificate?',
#               'What are the two methods to resolve wget certificate issues in the CLI environment?'],
#              '2f83dbe7': ['How do I use the backslash as an escape character in Git Bash for Windows?',
#               'What should I type in the terminal to set the backslash as an escape character in Git Bash for Windows?',
#               'What command allows the backslash to act as an escape character in Git Bash for Windows?',
#               'In Git Bash for Windows, how can I configure the backslash to be an escape character?',
#               'Is it necessary to include the backslash as an escape character in .bashrc for Git Bash on Windows?'],
#              '543ff080': ['How do I store secrets in GitHub Codespaces?',
#               'Where can I find instructions on managing Codespaces secrets?',
#               'What document provides information on handling GitHub Codespaces secrets?',
#               'How are account-specific secrets managed for GitHub Codespaces?',
#               'Is there a guide for storing secrets in GitHub Codespaces?'],
#              'd407d65b': ['How can I connect to the Docker daemon if I see an error with unix:///var/run/docker.sock?',
#               'What should I check if I cannot start the Docker daemon?',
#               'Is there a PowerShell command necessary for updating any settings related to Docker?',
#               'What can ensure the Docker daemon is running when seeing connection issues?',
#               'How do I update the WSL in PowerShell for Docker to work properly?'],
#              'c9375c56': ["What should Windows 10 Pro users do to enable Docker's Hyper-V backend?",
#               'Can Windows 10 Home users enable Hyper-V for Docker?',
#               'Where can Windows 10 Pro users find a tutorial to enable Hyper-V?',
#               'What must Windows 10 Home users use to run Docker if Hyper-V is unavailable?',
#               'What should you do if you encounter WslRegisterDistribution error 0x800701bc while installing WSL2?'],
#              'e866156b': ["What happens when you perform a 'docker pull' command in Docker?",
#               'Do I need to perform a docker login to fetch Docker images for this course?',
#               "What should I do if I get a 'requested access to the resource is denied' message after running 'docker pull'?",
#               "Why do I encounter a 'permission denied' error when creating a PostgreSQL Docker container with a mounted volume on macOS M1?",
#               "How can I solve the 'permission denied' error when trying to create a PostgreSQL Docker container on macOS M1?"],
#              '16370470': ["What should I do if I can't delete a local folder mounted to a Docker volume?",
#               'How can I delete a folder created by a PostgreSQL Docker container?',
#               "Why can't I simply drag a Docker-created folder to trash?",
#               "What does the command 'sudo rm -r -f docker_test/' do?",
#               "What does '-r' and '-f' specify when using the 'rm' command in Unix?"],
#              '316df755': ['How can I resolve Docker being stuck on settings or not starting on Windows 10 / 11?',
#               'What should I do if Docker is stuck on starting on my Windows computer?',
#               'Can Docker run using Hyper-V on the Pro Edition of Windows 10 / 11?',
#               'How do I switch Docker containers from Windows to Linux or vice versa?',
#               "What should I do if the Docker menu's upgrade option doesn't work?"],
#              'f3aa9252': ['Where should I run Docker commands, from the Windows file system or WSL file system?',
#               'Can I run Docker on Windows 10 Home Edition?',
#               'What should I do if Docker stays stuck after setting up WSL2 or Hyper-V?',
#               'Is following a tutorial necessary to make Docker work on Windows Home Edition?',
#               "What are the troubleshooting steps if Docker doesn't work after setup?"],
#              'a4abe7a5': ['Why should I store all code in my default Linux distro for Docker?',
#               'What backend does Docker use by default on Windows 10 Home and Windows 11 Home?',
#               'Where can I find more information on best practices for Docker?',
#               'What is the benefit of storing code in the default Linux distro when using Docker?',
#               'For which Windows versions is Docker running on the WSL2 backend by default?'],
#              'fb930700': ['What should I do if my Docker run command gives an error that the input device is not a TTY?',
#               'How can I fix the issue with Docker on Windows when using mintty?',
#               'Is there a way to always include winpty in my Docker commands?',
#               "What is the solution for Docker's TTY error on Windows?",
#               'How can I create an alias to use winpty with Docker commands?'],
#              'aa187680': ['How can I fix the issue where I cannot pip install on a Docker container in Windows?',
#               'What error message might I see if pip install fails in a Docker container on Windows?',
#               'What is a possible command to resolve pip install issues on Docker for Windows?',
#               "What does the error 'Temporary failure in name resolution' indicate in a Docker container?",
#               'Why might docker run with --dns=8.8.8.8 help with pip install issues?'],
#              'b000e899': ['Why is the ny_taxi_postgres_data folder empty even after running the Docker script?',
#               'What should I do if the ny_taxi_postgres_data folder remains empty in VS Code on Windows?',
#               'How can I make sure files are visible in the VS Code ny_taxi folder for the Docker setup?',
#               'Which command should I use to ensure the ny_taxi_postgres_data folder is populated in Windows?',
#               'How do I set the absolute path in the -v parameter for Docker on Windows to solve folder visibility issues?'],
#              '9c66759f': ['question1',
#               'question2',
#               'question3',
#               'question4',
#               'question5'],
#              'e3106e07': ['How can I resolve the error of changing permissions for /var/lib/postgresql/data when using Docker?',
#               'What is an alternative way to map a local directory to the PostgreSQL data directory in Docker?',
#               'How do I verify if the Docker volume dtc_postgres_volume_local has been created?',
#               'What does the error \'directory "/var/lib/postgresql/data" exists but is not empty\' mean and how can I resolve it?',
#               'What specific environment variables need to be set when running PostgreSQL in Docker?'],
#              '72229da5': ["What should I do if the way volume mapping is done in the course video doesn't work for me on Windows?",
#               "How can I adjust the volume mapping command on Windows if it automatically creates a folder called 'ny_taxi_postgres_data;C'?",
#               "What are some alternatives to the '-v' option for mounting volumes with Docker on Windows?",
#               "Is there a specific way to place quotes when using the '$(pwd)' command for volume mapping on Windows?",
#               'What command should I use on a Mac for Docker volume mapping?'],
#              '58c9f99f': ["How can I resolve the Docker error 'invalid mode: \\Program Files\\Git\\var\\lib\\postgresql\\data'?",
#               'What should I do if I encounter an invalid mode error in Docker on Windows?',
#               'What is the correct mounting path to use in Docker for PostgreSQL data on Windows?',
#               'Can you provide an example of a correct Docker mounting path for PostgreSQL data?',
#               "How do I correct the mounting path error in Docker for \\Program Files\\Git\\var\\lib\\postgresql\\data'?"],
#              'bc42139a': ['How do I fix the Docker build mount error that occurs during the second run?',
#               'Why should I avoid mounting the path on the second run when using Docker?',
#               'What command should I use for the second run to avoid the Docker error without mounting?',
#               'What environment variables are needed for the Docker POSTGRES container?',
#               'What ports should be mapped for the PostgreSQL Docker container?'],
#              'a146e3ee': ['Why am I seeing an error checking context during the docker build process?',
#               'How did the user ID of the directory cause a permission issue in docker build?',
#               'What files are necessary to avoid the docker build error mentioned in Module 1?',
#               'How can I change the permissions of a directory on Ubuntu to fix the docker build error?',
#               'Where can I find a more complete explanation of the docker build error and its solutions?'],
#              '593a85ba': ['Did I install Docker via snap if I received ERRO[0000] error waiting for container: context canceled?',
#               'How can I verify if Docker is installed via snap?',
#               'What should I do if I get \'error: unknown command "status", see \'snap help\'.\' while checking Docker status via snap?',
#               'Where can I properly install Docker if removing the snap package?',
#               'Why would I get a Bind for 0.0.0.0:5432 failed: port is a error?'],
#              '50bd1a71': ["What causes the error 'can’t stat /home/fhrzn/Projects/…./ny_taxi_postgres_data' in Docker?",
#               'How do I resolve the error related to permission issues in Docker on PopOS Linux?',
#               'Why is my folder appearing empty in PopOS Linux when trying to build Docker?',
#               'What command should I use to add permissions to my folder for Docker on PopOS?',
#               'Can you provide an example of a chmod command to fix Docker build errors?'],
#              'f409f751': ["What should I do if I get a 'failed to solve with frontend dockerfile.v0: failed to read dockerfile: error from sender: open ny_taxi_postgres_data: permission denied' error on Ubuntu/Linux?",
#               "Why might I encounter a 'permission denied' error when rebuilding a Docker container?",
#               "How can I grant permissions to the 'ny_taxi_postgres_data' folder to resolve Docker build errors?",
#               "What is the command to assign write access to the owner for the 'ny_taxi_postgres_data' directory?",
#               "If using 'sudo chmod -R 755' doesn't resolve the permission issue with Docker, what should I do next?"],
#              '7d217da3': ['How can I find out the name of a Docker network?',
#               'What command lists Docker networks?',
#               'Where can I check the names of Docker networks?',
#               'Which command helps me see Docker networks?',
#               'How do I see all available Docker networks?'],
#              '09081824': ["What should I do if I see an error that says the container name 'pg-database' is already in use?",
#               'How do I resolve a conflict error when restarting a Docker image with a network name?',
#               'What command should I use to stop a running Docker container causing a name conflict?',
#               "Is there an alternative to using 'docker run' to restart a Docker image without removing it?",
#               "Which commands are needed to remove a Docker container named 'pg-database'?"],
#              '4df80c55': ['What error message might I encounter when using Docker Compose that relates to a hostname issue?',
#               "How can I resolve the 'could not translate host name' error in Docker Compose?",
#               'What specific changes should I make to my ingestion script to fix the Docker hostname translation issue?',
#               'Which part of the Docker Compose setup should I check when facing hostname translation issues?',
#               'Can you provide an example of how to update network and database names to resolve Docker Compose errors?'],
#              '3aee7261': ['How can I enable nested virtualization for Docker on an Intel CPU?',
#               'How do I set up nested virtualization for Docker on an AMD CPU?',
#               'What command should I use to enable KVM nested virtualization on Intel?',
#               'What is the command for enabling nested virtualization on AMD for Docker?',
#               "Why can't I install Docker on a MacOS/Windows 11 VM running on top of Linux?"],
#              '6497b659': ['How can I manage Docker containers in VS Code?',
#               'What do I need to do to connect VS Code to Docker?',
#               'Can VS Code connect to Docker running on WSL2?',
#               'Where do I find the Docker extension in VS Code?',
#               'How do I stop a running Docker container?'],
#              'a02f2039': ['What should I do if my Docker container with PostgreSQL is not accepting any requests and logs indicate the database system is shut down?',
#               "Why am I getting a 'connection failed: server closed the connection unexpectedly' error when connecting to my PostgreSQL Docker container?",
#               'What does it mean if PostgreSQL server in my Docker container terminated abnormally?',
#               'How can I resolve the issue where my PostgreSQL Docker container is not processing requests?',
#               "What steps should I take if my PostgreSQL Docker container logs show 'Database directory appears to contain a database' and the system is shut down?"],
#              'c6db65aa': ['question1',
#               'question2',
#               'question3',
#               'question4',
#               'question5'],
#              'f476a606': ['How can I resolve the mounting error when using Docker-Compose with PostgreSQL?',
#               'What should I do if my Docker-Compose named volume for PostgreSQL is not being correctly used?',
#               "Why am I seeing an 'Operation not permitted' error in Docker-Compose for my PostgreSQL directory?",
#               'How can I inspect the location of my Docker-Compose named volume?',
#               'What steps can I take to ensure my Docker-Compose setup uses the correct PostgreSQL volume?'],
#              'e41b100c': ['How can I start my Docker containers in detached mode?',
#               'What should I do to resolve the error related to translating the hostname to address in Docker-Compose?',
#               'How can I check if my PostgreSQL database container is running?',
#               'What command do I use to view the logs for a specific Docker container?',
#               "What should I do if 'docker ps' does not show my pg-database container running?"],
#              'cd0f9300': ['What should I do if I lose database data and cannot run my Ingestion script successfully after executing `docker-compose up`?',
#               "What error might I receive if Docker Compose is unable to translate the host name 'pg-database'?",
#               'Why is Docker Compose creating its own default network in my setup?',
#               'How can I find the Docker Compose network name after executing `docker-compose up`?',
#               'What tools can I use if problems persist with pgcli?'],
#              '7f845a1c': ["How can I resolve the 'network not found' error in Docker-Compose?",
#               "What should I do if I'm unable to connect to the server at localhost:8080?",
#               'What naming convention should I follow for host names in Docker-Compose?',
#               'How should I configure the docker-compose.yml file to specify the same network for both containers?',
#               'What environment variables do I need to set for the PostgreSQL and Pgadmin containers in the docker-compose.yml file?'],
#              '36e54439': ["Why doesn't postgres persist its data to the mentioned path when using docker-compose on GCP?",
#               'How can I make PGAdmin data persist when using Docker-Compose on GCP?',
#               'What is a common issue with persisting PGAdmin contents on GCP using Docker-Compose?',
#               'What is the solution for making PGAdmin data persistent in Docker-Compose?',
#               'How should volumes be defined in Docker-Compose for PGAdmin to persist data on GCP?'],
#              '32e8450c': ['What should I do when my Docker engine stops and fails to fetch extensions?',
#               'Why does my Docker keep crashing even after I restart it?',
#               'How can I resolve the issue of Docker engine stopping and extension errors?',
#               'Is updating Docker a potential solution for continuous crashes?',
#               'What is the final solution if updating Docker does not fix the problem?'],
#              '96606db2': ['How can I persist pgAdmin configuration using Docker-Compose?',
#               'What do I need to add to the Docker-Compose YAML file to persist pgAdmin settings?',
#               'Where should the pgAdmin data be stored on the host machine for it to persist?',
#               'What permissions are required for pgAdmin to write to the folder on the host machine?',
#               'Which Docker-Compose command is used before running docker-compose up for pgAdmin configuration?'],
#              '0882bfac': ["What should I do if I encounter 'dial unix /var/run/docker.sock: connect: permission denied' while using Docker-Compose?",
#               'How do I make pgAdmin remember my previous database connections in Docker?',
#               'What steps are needed to create a volume for pgAdmin in Docker-Compose?',
#               'How do I add my user to the docker group to avoid permission issues?',
#               "What do I need to add to the docker-compose.yaml file to maintain pgAdmin's state?"],
#              '7d067f5c': ['Why is docker-compose still not available after modifying .bashrc?',
#               'What should I do if docker-compose is still unavailable after following the instructions in the 1.4.1 video?',
#               'How do I resolve the issue of docker-compose not being recognized after making changes to .bashrc?',
#               'What is a common reason for docker-compose commands not working after following the setup instructions in Module 1?',
#               'How can I ensure the docker-compose command works correctly after installation?'],
#              'ff352621': ['What can I do about the error getting credentials after running docker-compose up -d?',
#               'How can I resolve Docker-Compose credential errors?',
#               'What should I install to fix the Docker-Compose credential issue?',
#               'Where can I find more information about the Docker-Compose credential error solution?',
#               'Which package solves the Docker-Compose error getting credentials problem?'],
#              '2d653208': ['What steps should I follow if I have issues with Docker compose and data in Postgres in Module 1?',
#               'How do I create a new volume on Docker for the course setup?',
#               'What is the specific change needed in the docker-compose.yml file?',
#               'How should I set up the server configuration in pgadmin to match the docker-compose settings?',
#               'What should I check for in the terminal to ensure proper execution before starting data ingestion?'],
#              'f09ea61e': ['Where can I find the config.json file for Docker?',
#               'How do I fix the Docker Compose up -d error related to docker-credential-desktop?',
#               'What changes need to be made in the config.json file to resolve the issue with docker-credential-desktop?',
#               'What should I modify credsStore to in the Docker config.json file?',
#               'What is the next step after modifying the config.json file to fix the credential error?'],
#              'fbd3d2bb': ['What commands should I run to determine the appropriate docker-compose binary for WSL?',
#               'Where can I download the docker-compose binary for WSL?',
#               'How do I use uname to verify my system type for docker-compose?',
#               'What is the purpose of the uname -s command in configuring docker-compose for WSL?',
#               'Can you provide a curl command example for downloading docker-compose on WSL?'],
#              '0b014d0c': ['How can I resolve an undefined volume error in Docker-Compose on Windows/WSL in Module 1?',
#               "What should I do if service 'pgdatabase' refers to an undefined volume in Docker-Compose?",
#               'If my docker-compose.yaml causes an error with dtc_postgres_volume_local, how can I fix it?',
#               'What steps should I take to fix an invalid compose project error related to volume in Docker-Compose?',
#               'How do I properly define volumes in my docker-compose file to avoid errors?'],
#              'd21bff1d': ['What causes the WSL Docker directory permissions error?',
#               "How should I resolve permission issues if I'm encountering them with Docker and Windows?",
#               'Why should I use Docker volumes instead of the local WSL file system?',
#               "Is the 'user:' necessary when using Docker volumes?",
#               'Can you provide an example of a docker-compose.yaml file using Docker volumes?'],
#              '6afb7b55': ['If pgAdmin is not working in Windows, what causes the issue?',
#               "What solution do you propose if pgAdmin isn't functioning?",
#               'Which libraries are needed for pgAdmin to work with Postgres?',
#               'What alternative can be used if pgAdmin fails?',
#               'What command should I use to install psycopg2?'],
#              'b51c3b82': ["Why does the error 'Insufficient system resources exist to complete the requested service' occur in WSL?",
#               'How can I update the Windows Terminal to fix system resource issues in WSL?',
#               'Where can I find pending updates for the Windows Terminal?',
#               'What should I do after updating the Windows Terminal app?',
#               'How do I check for and update Windows security updates to resolve WSL issues?'],
#              '326af690': ['What should I do if WSL integration with Ubuntu stops unexpectedly with exit code 1?',
#               'How do I fix a DNS issue causing WSL integration with Ubuntu to fail unexpectedly?',
#               'What is the Windows registry command for enabling DNS cache after disabling it to fix the WSL issue?',
#               'What should I try if the WSL integration issue persists even after restarting Windows?',
#               'How can switching to Linux containers on Docker help resolve the unexpected stop issue with WSL integration?'],
#              'c2ec9047': ['Why do I face a permissions issue when trying to run the GPC VM through SSH in WSL2?',
#               'How can I fix the SSH permissions issue by using sudo in WSL2?',
#               'What is the command to change the permissions for the private key SSH file in WSL2?',
#               'How do I create a .ssh folder in the home directory of WSL2?',
#               'What steps should I follow to copy the .ssh folder from Windows to WSL2 and adjust permissions?'],
#              '3b711e73': ["How do I resolve the 'Could not resolve host name' error in WSL2?",
#               'Where should I create the .ssh/config file in WSL2?',
#               'What is the correct path for the config file in WSL2?',
#               'Can you provide the specific steps to fix the host name resolution issue in WSL2?',
#               'What should I include in the .ssh/config file for WSL2?'],
#              'cfe07c9d': ['What should I do when I receive a connection failure error in PGCLI for port 5432?',
#               'How can I fix the PGCLI error stating it could not receive data from the server?',
#               'What command can I use if PGCLI cannot send an SSL negotiation packet due to connection refusal?',
#               'How do I address a connection refused error when trying to connect to PGCLI on localhost?',
#               'What are the steps to resolve a PGCLI connection error for a local database?'],
#              'acf42bb8': ['What should I do if I encounter a PGCLI --help error in Module 1: Docker and Terraform?',
#               'When facing a PGCLI --help error, what is the likely cause?',
#               'Is an installation error a probable cause for a PGCLI --help error?',
#               'How can I troubleshoot a PGCLI --help error based on the FAQ record?',
#               'What should I check if there is an issue with PGCLI --help according to the FAQ record?'],
#              '176ce516': ['Do we have to run pgcli inside another Docker container in Module 1?',
#               'Can I run pgcli directly from my computer for the Module 1 labs?',
#               'Is it necessary to use another container for pgcli when working on the Docker and Terraform module?',
#               'How do I access the PostgreSQL database for Module 1 without using another container?',
#               'Is the PostgreSQL port 5432 mapped for local access in Module 1 of the course?'],
#              '3e5d1e9b': ["How can I fix the 'password authentication failed for user root' error in PGCLI when using Docker?",
#               'What should I do if I have a local Postgres installation causing port conflicts with Docker?',
#               'Which port should I use to connect to my Postgres Docker container if 5432 is occupied?',
#               'How do I find out if something is blocking port 5432 on my MacOS?',
#               'What is the command to unload the running PostgreSQL service on MacOS to free up the port?'],
#              '78833f32': ['How can I resolve the PermissionError when using PGCLI in Module 1?',
#               "What should I do if I get stuck at 'Solving environment' during conda install in Module 1?",
#               'Why am I getting [Errno 13] Permission denied while using pgcli in Module 1?',
#               'What is the recommended way to install pgcli to avoid the PermissionError mentioned in Module 1?',
#               "In Module 1, what alternatives can I try if conda install gets stuck at 'Solving environment'?"],
#              '63823f21': ["How do I resolve the 'no pq wrapper available' error in PGCLI?",
#               "What Python version do I need to have to install 'psycopg2-binary'?",
#               'How can I create a new environment with Python 3.9?',
#               'What command should I use to install pgcli using conda?',
#               'What additional step can I take if the initial solution for the ImportError problem does not work?'],
#              'b36ea564': ['In Module 1 on Docker and Terraform, what can I do if my Bash prompt is stuck on the password command for postgres?',
#               'What could be the reason for encountering \'FATAL: password authentication failed for user "root"\' even when inputting the correct password?',
#               'How can I resolve \'FATAL: password authentication failed for user "root"\' if I am using Windows and WSL?',
#               'What should I do to avoid \'FATAL: password authentication failed for user "root"\' error after closing the connection to the Postgres:13 image?',
#               'What command should I use if PGCLI is stuck on the password prompt for postgres on Windows?'],
#              'e2a46ce5': ['What do I do if I installed pgcli but it is not recognized in Git bash?',
#               'How can I fix pgcli not being recognized in Windows Terminal?',
#               'Where should I add the Python path to resolve pgcli command not found?',
#               'What command can I use to find the location of my Python packages?',
#               'What adjustment should I make if my Python installation is in a different directory?'],
#              '27bdbc3f': ['How can I run pgcli if I do not want to install it locally?',
#               'What should I do if I face issues running pgcli locally?',
#               'How do I use pgcli in a Docker container for this course?',
#               'What are the necessary parameters to run pgcli in Docker?',
#               'Can you provide an example command to run pgcli using Docker with course values?'],
#              'f7c5d8da': ['Does PGCLI require quotations for column names with capital letters in Docker and Terraform?',
#               "Why is 'PULocationID' not recognized in PGCLI?",
#               "How should 'PULocationID' be formatted in PGCLI to be recognized?",
#               'Are unquoted local identifiers case sensitive in PGCLI?',
#               "Can you explain why 'PULocationID' needs to be quoted in PGCLI?"],
#              'c91ad8f2': ["What should I do if I get the error column 'c.relhasoids does not exist' when using the command '\\d <database name>'?",
#               "How can I resolve the 'c.relhasoids does not exist' error in PGCLI?",
# ...
#               "Why am I seeing a warning about the requested image's platform in Module 4?",
#               'What is the correct syntax for building a Docker image with a platform tag in Module 4?',
#               "How can I fix the error about the image's platform not matching the host platform in Module 4?"],
#              '7aef625b': ['What should we use instead of the URL from s3.amazonaws.com to avoid an HTTP Error 403 in apply_model() in score.ipynb?',
#               'What URL replacement is recommended when encountering a HTTP 403 error for apply_model() in score.ipynb?',
#               "How can we solve the HTTP Error 403 Forbidden when using input_file in score.ipynb's apply_model()?",
#               'What is the solution provided by Ilnaz Salimov for HTTP Error 403 in the apply_model() function?',
#               'Who should I contact if facing an HTTP Error 403 Forbidden in apply_model() within score.ipynb?'],
#              'a3aa3a7d': ["What should I do if I encounter a ModuleNotFoundError for 'pipenv.patched.pip._vendor.urllib3.response'?",
#               "How can I resolve the error involving 'site-packages\\pipenv\\patched\\pip\\_vendor\\urllib3\\connectionpool.py'?",
#               'Is there a single command to reinstall the necessary pipenv module?',
#               'What command should I use to force-reinstall pipenv?',
#               'How can I ensure my installation for requests is updated?'],
#              'd2719204': ['What should I do if I get a login prompt in Grafana after running docker-compose up?',
#               'What are the default username and password for Grafana login?',
#               'Where can I find the login details for Grafana in Module 5?',
#               'How can I set a new password in Grafana after the initial login?',
#               'Who provided the solution for the Grafana login issue in the FAQ?'],
#              '30b8e8e6': ['What is the main issue when starting monitoring services in Linux as shown in video 5.2?',
#               "Why do services not start when using 'docker compose up --build' in Linux?",
#               'How should we correctly start services using docker-compose in Linux?',
#               "What specific command should be used in Linux instead of 'docker compose up --build'?",
#               'Who provided the solution for the error encountered in video 5.2?'],
#              'f33fc6e9': ["What should I do if I encounter a KeyError 'content-length' when running prepare.py in Module 5?",
#               "Why am I getting a KeyError 'content-length' while downloading taxi data using prepare.py?",
#               "How can I fix the issue of KeyError 'content-length' in the prepare.py script?",
#               'What is the updated URL to replace for downloading taxi data in the prepare.py script?',
#               "Can you provide a solution for the KeyError 'content-length' error encountered in Module 5's prepare.py?"],
#              'd828de2a': ["In what scenario might the service return 'Max retries exceeded with url: /api'?",
#               'What caused the evidently service to exit with code 2?',
#               "What is the first suggested solution if 'from pyarrow import parquet as pq' cannot be imported?",
#               'What should be the second step if installing pyarrow doesn’t resolve the issue?',
#               'What can be done if neither installing pyarrow nor restarting the machine solves the evidently service issue?'],
#              '03f20ec1': ['What causes a ValueError for incorrect item in Module 5?',
#               'How can I fix a ValueError in Module 5 related to metric or metric preset?',
#               'What is a likely mistake leading to a ValueError in evidently?',
#               'How do I resolve a metric-related ValueError in evidently? ',
#               'What error arises from forgetting parentheses in Module 5 and how to fix it?'],
#              '249726fe': ['What causes an error when using RegressionQualityMetric()?',
#               'What target is necessary for RegressionQualityMetric()?',
#               'How can I avoid an error with RegressionQualityMetric()?',
#               'What should be added to current_data for using RegressionQualityMetric()?',
#               'Who provided the answer regarding RegressionQualityMetric()?'],
#              '4e492af0': ['What happens if the array has 0 samples in Module 5?',
#               'Why might I encounter a ValueError mentioning 0 sample(s) in shape=(0,6)?',
#               'What does it mean when the training dataset is empty in monitoring?',
#               'How can I solve the issue of having an array with 0 samples?',
#               'Who contributed the solution for adjusting the start date in Module 5?'],
#              '10011dc1': ["Why am I getting 'target columns' and 'prediction columns' not present errors?",
#               'What should I do after getting errors when adding a new metric?',
#               'Where can I find what is required or optional for adding a metric?',
#               'Does DatasetCorrelationsMetric require any parameters?',
#               'What does DatasetCorrelationsMetric evaluate for?'],
#              '92fb909a': ['What should I do if the standard login in Grafana fails?',
#               'How can I fix an error using admin/admin credentials in Grafana?',
#               'What command solves the login issue in Grafana?',
#               "Who provided the solution for Grafana's standard login error?",
#               'Where should I run the command to reset the admin password in Grafana?'],
#              '2b8cb640': ['What steps can I take if Grafana charts are not updating during metric generation?',
#               'How should I configure the refresh interval in Grafana to ensure charts update?',
#               'What timezone setting should I use with `pytz.timezone` for Grafana updates?',
#               'Why might my Grafana charts stop receiving updates while the script is running?',
#               'What are the key considerations for ensuring Grafana charts receive updates?'],
#              'd4ceab0b': ['What should I do if the Prefect server does not run locally in Module 5?',
#               'How can I describe the problem when Prefect server stops immediately after starting?',
#               'What is the alternative method to run a script if the Prefect server fails locally?',
#               'What command should be used to start the Prefect server?',
#               'Where should I report issues if I encounter problems with Prefect server?'],
#              '482e575f': ['What should I do if I get a no disk space left error when running docker compose up?',
#               'How can I identify what’s consuming disk space before pruning with Docker?',
#               'Which Docker command helps remove unused build cache, containers, and images?',
#               'Who provided the solution for the no disk space left error in Module 5?',
#               'What command can be used to check disk space usage in Docker?'],
#              '33e775eb': ['How can I solve the issue of failed to listen on :::8080 while running docker-compose up --build?',
#               'What command should be added to the adminer block in the yml file to fix the php_network_getaddresses error?',
#               'Where exactly do I add the command to resolve the getaddrinfo failed error?',
#               "What is the reason given for the error 'Address family for hostname not supported' when using docker-compose?",
#               'Who provided the solution to the failed to listen on :::8080 problem and what is their email?'],
#              '19a3d34a': ['How can I generate charts similar to Evidently inside Grafana?',
#               'What kind of Grafana panels can be used to replicate Evidently charts?',
#               'Is there a native way to recreate Evidently dashboards in Grafana quickly?',
#               'What information is necessary to design Evidently-like plots in Grafana?',
#               'How can I export Evidently output to recreate visualizations externally?'],
#              '55c68f23': ["What is causing the 'Unable to locate credentials' error in localstack with Kinesis?",
#               "How can I fix the error message 'Unable to locate credentials' in the print statement of test_docker.py?",
#               'What environment variables need to be added in the docker-compose.yaml to fix the credentials issue?',
#               'Do the values of AWS_ACCESS_KEY_ID and AWS_SECRET_ACCESS_KEY need to be specific when fixing the credentials error?',
#               'What command can be used as an alternative solution to configure AWS credentials for localstack?'],
#              '54020f0a': ['Why do I get an error about an incompatible location constraint when I create a bucket with boto3?',
#               'What is the exact error message when creating a bucket with an unspecified location constraint in boto3?',
#               'How can I fix the IllegalLocationConstraintException error in localstack while creating a bucket using boto3?',
#               'What change in the create_bucket method helps avoid the unspecified location constraint error?',
#               'Which parameter should be added to the create_bucket method to specify the region for the bucket?'],
#              'b6249d2c': ['How can I fix the error <botocore.awsrequest.AWSRequest object> after running an AWS CLI command?',
#               'What are the steps to resolve the error <botocore.awsrequest.AWSRequest object at 0x7fbaf2666280> in AWS CLI?',
#               'What environment variables should I set to fix the error in AWS CLI?',
#               'Is the value of AWS_DEFAULT_REGION, AWS_ACCESS_KEY_ID, and AWS_SECRET_ACCESS_KEY significant when fixing an AWS CLI error?',
#               'Who provided the solution for the AWS CLI error <botocore.awsrequest.AWSRequest object>?'],
#              '31543d95': ['What should I check if I get a mapping values error during pre-commit?',
#               "What does the error 'mapping values are not allowed in this context' mean during a commit?",
#               "How do I fix the 'mapping values' error in my pre-commit hooks?",
#               "Why aren't pre-commit hooks running due to a mapping values error?",
#               'What specific indentation is required in .pre-commit-config.yaml to avoid errors?'],
#              'e147bbb6': ["What should I do if I can't reconfigure pytest after switching folders in Module 6?",
#               'How can I delete previous pytest configurations?',
#               'What folder should be removed to reset pytest settings?',
#               'How do I reconfigure pytest if tests were previously run in another folder?',
#               'Which folder contains the .vscode directory that should be removed to reset pytest?'],
#              'dc55657f': ['In Module 6, how can I fix the issue of getting empty records from Kinesis?',
#               'What additional flag should I add to the Kinesis get records command in video 6.3?',
#               'How do I modify the Kinesis get records call to avoid empty results as mentioned in section Module 6?',
#               'What workaround is provided in the solution for empty Records in Kinesis when following video 6.3?',
#               'In video 6.3 at minute 11:23, what should I add to the Kinesis command to get records?'],
#              'f6979915': ['What is the error when executing git commit after creating a pre-commit yaml file in Powershell?',
#               'Which file is causing the utf-8 encoding error in Git commit?',
#               'What is the error message for the utf-8 encoding issue in Powershell?',
#               'How can I solve the utf-8 encoding error when creating a pre-commit yaml file?',
#               'Who provided the solution for setting utf-8 encoding for the pre-commit yaml file?'],
#              '1076a121': ["How can I fix the error 'PythonInfo' object has no attribute 'version_nodot' during git commit with pre-commit hook?",
#               "What is indicated by the error 'AttributeError: 'PythonInfo' object has no attribute 'version_nodot'?",
#               "What does the return code 1 signify when encountering 'PythonInfo' object error?",
#               "Who added the solution for fixing the 'PythonInfo' object error during a git commit?",
#               "What commands should be used to clear app-data of the virtualenv to resolve 'PythonInfo' error?"],
#              'aa203ca7': ["What should I do if I get a 'module not found' error when running tests with Pytest for custom packages?",
#               "Why does running 'pytest ./test/unit_tests' result in 'No module named production'?",
#               'What is the correct command to run tests with Pytest from the sources directory?',
#               "Why does running 'python test_model_service.py' work but 'pytest ./test/unit_tests' does not?",
#               'How can I ensure Pytest can find my custom packages during testing?'],
#              '8b04605d': ["What is the solution when 'No module named production' error occurs during pytest hook using pre-commit in a project with custom packages in the source code?",
#               "What changes need to be made in the pre-commit hook to fix 'No module named production' error during pytest?",
#               "Why does git commit -t 'test' raise 'No module named production' when calling pytest hook in a project with custom packages?",
#               'How should the run.sh file be configured to set the right directory and run pytest for the pre-commit hook?',
#               'What export command should be used in run.sh to fix the module not found error in pytest hook?'],
#              'a3b9af04': ['What is the error code associated with a permission denied error when running a GitHub Action script?',
#               'Where should the unit tests script be located in the working directory?',
#               'What command should I use to add execution permission to a script in a GitHub repository?',
#               'Who provided the solution to the permission denied error in GitHub Actions?',
#               'What is a common permission error encountered when running scripts with GitHub Actions?'],
#              'b16aae74': ['How can I manage resource usage when my docker-compose file has many containers?',
#               'What can I do to run only a specific group of containers for testing?',
#               'What command should I use to start a service with a profile in docker-compose?',
#               'How do I define a profile for a service in a docker-compose file?',
#               'Who contributed the solution for managing multiple Docker containers with profiles?'],
#              '66326a87': ['What should you verify if facing problems with integration tests and Kinesis in Module 6?',
#               'How can mismatched AWS regions affect your integration tests?',
#               'What file should be checked to ensure the AWS region is set correctly for docker-compose?',
#               'What is an example of setting the AWS region in the local configuration for Module 6?',
#               'Who provided the solution for AWS region settings in docker-compose and local config?'],
#              'fb3c4150': ['What should I do if the Pre-commit command fails with isort?',
#               'Which version of isort should be set to fix the Pre-commit issue?',
#               'Who provided the solution to the Pre-commit issue with isort?',
#               'Can you tell me the module where Pre-commit issues are discussed?',
#               'What is the recommended isort version for Pre-commit command?'],
#              '886d1617': ['How should I destroy infrastructure created using the CD-Deploy Action in AWS?',
#               'What is the first step to destroy AWS infrastructure created via GitHub Actions?',
#               'Can I destroy infrastructure created with GitHub Actions from my local setup?',
#               'What command initializes Terraform with specific backend configuration before destroying infrastructure?',
#               'How do you specify the variable file when running terraform destroy?']})
